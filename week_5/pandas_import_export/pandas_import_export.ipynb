# %% [markdown]
# <div style="float:right; padding-top: 15px; padding-right: 15px">
#     <div>
#         <a href="https://whiteboxml.com">
#             <img src="https://whiteboxml.com/static/img/logo/black_bg_white.svg" width="250">
#         </a>
#     </div>
# </div>

# %% [markdown]
# # Pandas import - export

# %%
import pandas as pd

# %% [markdown]
# ## 1. CSV

# %%
# import comma-separated variable file
df = pd.read_csv('data/vehicles.csv')

df.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550
# 2               555.437500            2100
# 3               683.615385            2550
# 4               555.437500            2550

# %%
# import tab-delimited file
df_tab = pd.read_csv('data/vehicles_tab.txt', sep='\t')

df_tab.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550
# 2               555.437500            2100
# 3               683.615385            2550
# 4               555.437500            2550

# %%
# import pipe-delimited file
df_pipe = pd.read_csv('data/vehicles_pipe.txt', sep='|')

df_pipe.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550
# 2               555.437500            2100
# 3               683.615385            2550
# 4               555.437500            2550

# %%
import os

output_folder = 'output'
if not os.path.exists(output_folder):
    os.mkdir(output_folder)

# %%
df.to_csv(f'{output_folder}/vehicles.csv', index=False)

# %%
# now with index
df_tab.to_csv(f'{output_folder}/vehicles_tab.csv', sep='\t')

# %% [markdown]
# ## 2. Excel

# %%
# !pip install xlrd
# Out:
# Requirement already satisfied: xlrd in /home/ubuntu/miniconda3/envs/ironhack_env/lib/python3.7/site-packages (1.2.0)

# %%
df_excel = pd.read_excel('data/vehicles.xlsx')

df_excel.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0          4  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1          6  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2          4  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3          6  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4          6  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550
# 2               555.437500            2100
# 3               683.615385            2550
# 4               555.437500            2550

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /home/ubuntu/miniconda3/envs/ironhack_env/lib/python3.7/site-packages (3.0.3)
# Requirement already satisfied: et-xmlfile in /home/ubuntu/miniconda3/envs/ironhack_env/lib/python3.7/site-packages (from openpyxl) (1.0.1)
# Requirement already satisfied: jdcal in /home/ubuntu/miniconda3/envs/ironhack_env/lib/python3.7/site-packages (from openpyxl) (1.4.1)

# %%
df_excel.to_excel(f'{output_folder}/vehicles.xlsx', index=False)

# %% [markdown]
# ## 3. JSON

# %%
df_json = pd.read_json('data/vehicles.json', orient='records')

df_json.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0          4  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1          6  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2          4  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3          6  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4          6  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550
# 2               555.437500            2100
# 3               683.615385            2550
# 4               555.437500            2550

# %%
df_json.to_json(f'{output_folder}/vehicles.json', orient='records')

# %%
df_json.to_json(f'{output_folder}/vehicles_split.json', orient='split')

# %%
df_json.to_json(f'{output_folder}/vehicles_columns.json', orient='columns')

# %% [markdown]
# ## 4. Parquet

# %%
# !pip install pyarrow
# Out:
# Requirement already satisfied: pyarrow in /home/ubuntu/miniconda3/envs/ironhack_env/lib/python3.7/site-packages (0.17.1)
# Requirement already satisfied: numpy>=1.14 in /home/ubuntu/miniconda3/envs/ironhack_env/lib/python3.7/site-packages (from pyarrow) (1.18.1)

# %%
df_parquet = pd.read_parquet(f'data/vehicles.parquet')

df_parquet.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0          4  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1          6  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2          4  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3          6  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4          6  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550
# 2               555.437500            2100
# 3               683.615385            2550
# 4               555.437500            2550

# %%
df_parquet.to_parquet(f'{output_folder}/vehicles.parquet')

# %% [markdown]
# ## 5. Database

# %%
# !pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in /home/ubuntu/miniconda3/envs/ironhack_env/lib/python3.7/site-packages (1.3.17)

# %%
from sqlalchemy import create_engine

# %%
sqlitedb_path = '../../week_3/sql_introduction/data/chinook.db'

# %%
engine = create_engine(f'sqlite:///{sqlitedb_path}')

# %%
# list all tables in database
pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table'", engine)
# Out:
#                name
# 0            albums
# 1   sqlite_sequence
# 2           artists
# 3         customers
# 4         employees
# 5            genres
# 6          invoices
# 7     invoice_items
# 8       media_types
# 9         playlists
# 10   playlist_track
# 11           tracks
# 12     sqlite_stat1

# %%
# query one of them
df_sqlite = pd.read_sql_query("select * from customers", engine)

df_sqlite.head()
# Out:
#    CustomerId  FirstName     LastName  \
# 0           1       Luís    Gonçalves
# 1           2     Leonie       Köhler
# 2           3   François     Tremblay
# 3           4      Bjørn       Hansen
# 4           5  František  Wichterlová
#
#                                             Company  \
# 0  Embraer - Empresa Brasileira de Aeronáutica S.A.
# 1                                              None
# 2                                              None
# 3                                              None
# 4                                  JetBrains s.r.o.
#
#                            Address                 City State         Country  \
# 0  Av. Brigadeiro Faria Lima, 2170  São José dos Campos    SP          Brazil
# 1          Theodor-Heuss-Straße 34            Stuttgart  None         Germany
# 2                1498 rue Bélanger             Montréal    QC          Canada
# 3                 Ullevålsveien 14                 Oslo  None          Norway
# 4                    Klanova 9/506               Prague  None  Czech Republic
#
#   PostalCode               Phone                 Fax  \
# 0  12227-000  +55 (12) 3923-5555  +55 (12) 3923-5566
# 1      70174    +49 0711 2842222                None
# 2    H2G 1A7   +1 (514) 721-4711                None
# 3       0171     +47 22 44 22 22                None
# 4      14700    +420 2 4172 5555    +420 2 4172 5555
#
#                       Email  SupportRepId
# 0      luisg@embraer.com.br             3
# 1     leonekohler@surfeu.de             5
# 2       ftremblay@gmail.com             3
# 3     bjorn.hansen@yahoo.no             4
# 4  frantisekw@jetbrains.com             4

# %%
two_lines_query = """
select * from customers
where FirstName='Leonie'
"""

# %%
df_sqlite = pd.read_sql_query(two_lines_query, engine)

df_sqlite.head()
# Out:
#    CustomerId FirstName LastName Company                  Address       City  \
# 0           2    Leonie   Köhler    None  Theodor-Heuss-Straße 34  Stuttgart
#
#   State  Country PostalCode             Phone   Fax                  Email  \
# 0  None  Germany      70174  +49 0711 2842222  None  leonekohler@surfeu.de
#
#    SupportRepId
# 0             5

# %%
df_sqlite.to_sql('test_write', engine, if_exists='replace', index=False)

# %%
pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table'", engine)
# Out:
#                name
# 0            albums
# 1   sqlite_sequence
# 2           artists
# 3         customers
# 4         employees
# 5            genres
# 6          invoices
# 7     invoice_items
# 8       media_types
# 9         playlists
# 10   playlist_track
# 11           tracks
# 12     sqlite_stat1
# 13       test_write

# %%
drop_query = 'drop table test_write'

# pd.read_sql_query(drop_query, engine)

with engine.begin() as conn:
    conn.execute(drop_query)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/miniconda3/envs/ironhack_env/lib/python3.7/site-packages/sqlalchemy/engine/result.py in _fetchall_impl(self)
#    1229         try:
# -> 1230             return self.cursor.fetchall()
#    1231         except AttributeError as err:
#
# AttributeError: 'NoneType' object has no attribute 'fetchall'
#
# The above exception was the direct cause of the following exception:
#
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-61-db70918da185> in <module>
#       1 drop_query = 'drop table test_write'
#       2
# ----> 3 pd.read_sql_query(drop_query, engine)
#       4
#       5 # with engine.begin() as conn:
#
# ~/miniconda3/envs/ironhack_env/lib/python3.7/site-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     330         coerce_float=coerce_float,
#     331         parse_dates=parse_dates,
# --> 332         chunksize=chunksize,
#     333     )
#     334
#
# ~/miniconda3/envs/ironhack_env/lib/python3.7/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1229             )
#    1230         else:
# -> 1231             data = result.fetchall()
#    1232             frame = _wrap_result(
#    1233                 data,
#
# ~/miniconda3/envs/ironhack_env/lib/python3.7/site-packages/sqlalchemy/engine/result.py in fetchall(self)
#    1287         except BaseException as e:
#    1288             self.connection._handle_dbapi_exception(
# -> 1289                 e, None, None, self.cursor, self.context
#    1290             )
#    1291
#
# ~/miniconda3/envs/ironhack_env/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1519                 )
#    1520             else:
# -> 1521                 util.raise_(exc_info[1], with_traceback=exc_info[2])
#    1522
#    1523         finally:
#
# ~/miniconda3/envs/ironhack_env/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~/miniconda3/envs/ironhack_env/lib/python3.7/site-packages/sqlalchemy/engine/result.py in fetchall(self)
#    1282
#    1283         try:
# -> 1284             l = self.process_rows(self._fetchall_impl())
#    1285             self._soft_close()
#    1286             return l
#
# ~/miniconda3/envs/ironhack_env/lib/python3.7/site-packages/sqlalchemy/engine/result.py in _fetchall_impl(self)
#    1230             return self.cursor.fetchall()
#    1231         except AttributeError as err:
# -> 1232             return self._non_result([], err)
#    1233
#    1234     def _non_result(self, default, err=None):
#
# ~/miniconda3/envs/ironhack_env/lib/python3.7/site-packages/sqlalchemy/engine/result.py in _non_result(self, default, err)
#    1239                     "It has been closed automatically."
#    1240                 ),
# -> 1241                 replace_context=err,
#    1242             )
#    1243         elif self.closed:
#
# ~/miniconda3/envs/ironhack_env/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.

# %%
pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table'", engine)
# Out:
#                name
# 0            albums
# 1   sqlite_sequence
# 2           artists
# 3         customers
# 4         employees
# 5            genres
# 6          invoices
# 7     invoice_items
# 8       media_types
# 9         playlists
# 10   playlist_track
# 11           tracks
# 12     sqlite_stat1

# %% [markdown]
# <div style="padding-top: 25px; float: right">
#     <div>
#         <i>&nbsp;&nbsp;© Copyright by</i>
#     </div>
#     <div>
#         <a href="https://whiteboxml.com">
#             <img src="https://whiteboxml.com/static/img/logo/black_bg_white.svg" width="125">
#         </a>
#     </div>
# </div>
