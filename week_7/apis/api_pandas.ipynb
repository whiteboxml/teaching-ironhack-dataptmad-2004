# %% [markdown]
# <div style="float:right; padding-top: 15px; padding-right: 15px">
#     <div>
#         <a href="https://whiteboxml.com">
#             <img src="https://whiteboxml.com/static/img/logo/black_bg_white.svg" width="250">
#         </a>
#     </div>
# </div>

# %% [markdown]
# # APIs

# %% [markdown]
# Application owners will often create APIs (or Application Programming Interface) so that their applications can talk to other applications. An API is a set of programmatic instructions for accessing software applications, and the data that comes from APIs typically contains some sort of structure (such as JSON)

# %% [markdown]
# The term REST (Representational State Transfer) is any interface between systems that uses HTTP for getting data or doing operations over these data in any possible format, such as XML or JSON

# %% [markdown]
# Fake REST API: https://jsonplaceholder.typicode.com/

# %% [markdown]
# ## 1. Simple Response

# %%
import requests

response = requests.get('https://jsonplaceholder.typicode.com/todos')

json_data = response.json()

json_data[0:5]
# Out:
# [{'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False},
#  {'userId': 1,
#   'id': 2,
#   'title': 'quis ut nam facilis et officia qui',
#   'completed': False},
#  {'userId': 1, 'id': 3, 'title': 'fugiat veniam minus', 'completed': False},
#  {'userId': 1, 'id': 4, 'title': 'et porro tempora', 'completed': True},
#  {'userId': 1,
#   'id': 5,
#   'title': 'laboriosam mollitia et enim quasi adipisci quia provident illum',
#   'completed': False}]

# %%
import pandas as pd

data = pd.DataFrame(json_data)
data.head()
# Out:
#    userId  id                                              title  completed
# 0       1   1                                 delectus aut autem      False
# 1       1   2                 quis ut nam facilis et officia qui      False
# 2       1   3                                fugiat veniam minus      False
# 3       1   4                                   et porro tempora       True
# 4       1   5  laboriosam mollitia et enim quasi adipisci qui...      False

# %% [markdown]
# ## 2. Nested Response

# %%
response = requests.get('https://api.github.com/events')

json_data = response.json()

json_data[0:2]
# Out:
# [{'id': '12660240140',
#   'type': 'CreateEvent',
#   'actor': {'id': 28953407,
#    'login': 'pannalalaxmi',
#    'display_login': 'pannalalaxmi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pannalalaxmi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/28953407?'},
#   'repo': {'id': 273039630,
#    'name': 'pannalalaxmi/devtraining-needit-orlando',
#    'url': 'https://api.github.com/repos/pannalalaxmi/devtraining-needit-orlando'},
#   'payload': {'ref': 'PerformanceAnalytics',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'This repository is used by the developer site training content, Orlando release. It is used for the Build the NeedIt App, Scripting in ServiceNow, Application Security, Importing Data, Automating Application Logic, Flow Designer, REST Integrations, Reporting and Analytics, Domain Separation, Mobile Applications, and Context-sensitive Help courses.',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-06-17T17:54:14Z'},
#  {'id': '12660240125',
#   'type': 'PushEvent',
#   'actor': {'id': 66938086,
#    'login': 'mmcvuur',
#    'display_login': 'mmcvuur',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mmcvuur',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/66938086?'},
#   'repo': {'id': 273043317,
#    'name': 'mmcvuur/LottoGuess',
#    'url': 'https://api.github.com/repos/mmcvuur/LottoGuess'},
#   'payload': {'push_id': 5244768719,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'b61a68009606ba8338e14519731af866f8495189',
#    'before': '30115f7cceebde6ed7b32373f83b06b2d192f08d',
#    'commits': [{'sha': 'b61a68009606ba8338e14519731af866f8495189',
#      'author': {'email': 'mmcvuur@gmail.com', 'name': 'Michael M'},
#      'message': 'Create README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mmcvuur/LottoGuess/commits/b61a68009606ba8338e14519731af866f8495189'}]},
#   'public': True,
#   'created_at': '2020-06-17T17:54:14Z'}]

# %%
for json_item in json_data:
    try:
        print(json_item['payload']['commits'][0]['author']['email'])
    except:
        print('not a commit')
# Out:
# not a commit
# mmcvuur@gmail.com
# 61796525+tobias0709@users.noreply.github.com
# not a commit
# not a commit
# not a commit
# not a commit
# not a commit
# dmiluski@gmail.com
# 40006040+alexym1@users.noreply.github.com
# not a commit
# 43325903+bky-25@users.noreply.github.com
# dev@jeffreystarke.me
# not a commit
# kunyuhe@uchicago.edu
# not a commit
# not a commit
# not a commit
# not a commit
# matheus.muriel@outlook.com
# not a commit
# not a commit
# celine.durniak@esss.se
# not a commit
# craigcockrum@MacBook-Pro.local
# not a commit
# not a commit
# not a commit
# teikmenglee@yahoo.com
# drews_view@hotmail.com

# %% [markdown]
# ### 2.1 Raw pandas

# %%
data = pd.DataFrame(json_data)
data.head()
# Out:
#             id         type  \
# 0  12660240140  CreateEvent
# 1  12660240125    PushEvent
# 2  12660240124    PushEvent
# 3  12660240133   WatchEvent
# 4  12660240127  IssuesEvent
#
#                                                actor  \
# 0  {'id': 28953407, 'login': 'pannalalaxmi', 'dis...
# 1  {'id': 66938086, 'login': 'mmcvuur', 'display_...
# 2  {'id': 61796525, 'login': 'tobias0709', 'displ...
# 3  {'id': 1496283, 'login': 'mcg-web', 'display_l...
# 4  {'id': 34471120, 'login': 'RyazMax', 'display_...
#
#                                                 repo  \
# 0  {'id': 273039630, 'name': 'pannalalaxmi/devtra...
# 1  {'id': 273043317, 'name': 'mmcvuur/LottoGuess'...
# 2  {'id': 256240229, 'name': 'buscandoaverroes/HR...
# 3  {'id': 158382, 'name': 'nrk/redis-lua', 'url':...
# 4  {'id': 272197997, 'name': 'vovac12/ecology', '...
#
#                                              payload  public  \
# 0  {'ref': 'PerformanceAnalytics', 'ref_type': 'b...    True
# 1  {'push_id': 5244768719, 'size': 1, 'distinct_s...    True
# 2  {'push_id': 5244768714, 'size': 1, 'distinct_s...    True
# 3                              {'action': 'started'}    True
# 4  {'action': 'opened', 'issue': {'url': 'https:/...    True
#
#              created_at  org
# 0  2020-06-17T17:54:14Z  NaN
# 1  2020-06-17T17:54:14Z  NaN
# 2  2020-06-17T17:54:14Z  NaN
# 3  2020-06-17T17:54:14Z  NaN
# 4  2020-06-17T17:54:14Z  NaN

# %% [markdown]
# Access the first element of column "actor" in 4 different ways:

# %%
column = 'actor'

# %%
data[column][0]
# Out:
# {'id': 28953407,
#  'login': 'pannalalaxmi',
#  'display_login': 'pannalalaxmi',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/pannalalaxmi',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/28953407?'}

# %%
data.loc[0, column]
# Out:
# {'id': 28953407,
#  'login': 'pannalalaxmi',
#  'display_login': 'pannalalaxmi',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/pannalalaxmi',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/28953407?'}

# %%
data.actor[0]
# Out:
# {'id': 28953407,
#  'login': 'pannalalaxmi',
#  'display_login': 'pannalalaxmi',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/pannalalaxmi',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/28953407?'}

# %%
data.iloc[0, 2]
# Out:
# {'id': 28953407,
#  'login': 'pannalalaxmi',
#  'display_login': 'pannalalaxmi',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/pannalalaxmi',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/28953407?'}

# %%
data[column].head()
# Out:
# 0    {'id': 28953407, 'login': 'pannalalaxmi', 'dis...
# 1    {'id': 66938086, 'login': 'mmcvuur', 'display_...
# 2    {'id': 61796525, 'login': 'tobias0709', 'displ...
# 3    {'id': 1496283, 'login': 'mcg-web', 'display_l...
# 4    {'id': 34471120, 'login': 'RyazMax', 'display_...
# Name: actor, dtype: object

# %%
dict(data[column])
# Out:
# {0: {'id': 28953407,
#   'login': 'pannalalaxmi',
#   'display_login': 'pannalalaxmi',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/pannalalaxmi',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/28953407?'},
#  1: {'id': 66938086,
#   'login': 'mmcvuur',
#   'display_login': 'mmcvuur',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/mmcvuur',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/66938086?'},
#  2: {'id': 61796525,
#   'login': 'tobias0709',
#   'display_login': 'tobias0709',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/tobias0709',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/61796525?'},
#  3: {'id': 1496283,
#   'login': 'mcg-web',
#   'display_login': 'mcg-web',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/mcg-web',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/1496283?'},
#  4: {'id': 34471120,
#   'login': 'RyazMax',
#   'display_login': 'RyazMax',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/RyazMax',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/34471120?'},
#  5: {'id': 1505180,
#   'login': 'seattletimes',
#   'display_login': 'seattletimes',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/seattletimes',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/1505180?'},
#  6: {'id': 60754,
#   'login': 'nebhale',
#   'display_login': 'nebhale',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/nebhale',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/60754?'},
#  7: {'id': 1505180,
#   'login': 'seattletimes',
#   'display_login': 'seattletimes',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/seattletimes',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/1505180?'},
#  8: {'id': 53469,
#   'login': 'alfwatt',
#   'display_login': 'alfwatt',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/alfwatt',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/53469?'},
#  9: {'id': 40006040,
#   'login': 'alexym1',
#   'display_login': 'alexym1',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/alexym1',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/40006040?'},
#  10: {'id': 1505180,
#   'login': 'seattletimes',
#   'display_login': 'seattletimes',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/seattletimes',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/1505180?'},
#  11: {'id': 43325903,
#   'login': 'bky-25',
#   'display_login': 'bky-25',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/bky-25',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/43325903?'},
#  12: {'id': 1320020,
#   'login': 'starkej2',
#   'display_login': 'starkej2',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/starkej2',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/1320020?'},
#  13: {'id': 1657309,
#   'login': 'stevehadd',
#   'display_login': 'stevehadd',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/stevehadd',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/1657309?'},
#  14: {'id': 42744223,
#   'login': 'KunyuHe',
#   'display_login': 'KunyuHe',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/KunyuHe',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/42744223?'},
#  15: {'id': 20636269,
#   'login': 'chrisvsanchez',
#   'display_login': 'chrisvsanchez',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/chrisvsanchez',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/20636269?'},
#  16: {'id': 1505180,
#   'login': 'seattletimes',
#   'display_login': 'seattletimes',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/seattletimes',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/1505180?'},
#  17: {'id': 29139614,
#   'login': 'renovate[bot]',
#   'display_login': 'renovate',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/renovate[bot]',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/29139614?'},
#  18: {'id': 307709,
#   'login': 'gustafnk',
#   'display_login': 'gustafnk',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/gustafnk',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/307709?'},
#  19: {'id': 19895466,
#   'login': 'MatheusMuriel',
#   'display_login': 'MatheusMuriel',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/MatheusMuriel',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/19895466?'},
#  20: {'id': 6749661,
#   'login': 'test987987',
#   'display_login': 'test987987',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/test987987',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/6749661?'},
#  21: {'id': 9154160,
#   'login': 'krautcat',
#   'display_login': 'krautcat',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/krautcat',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/9154160?'},
#  22: {'id': 7889724,
#   'login': 'celinedurniak',
#   'display_login': 'celinedurniak',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/celinedurniak',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/7889724?'},
#  23: {'id': 1505180,
#   'login': 'seattletimes',
#   'display_login': 'seattletimes',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/seattletimes',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/1505180?'},
#  24: {'id': 65249183,
#   'login': 'ubercraig',
#   'display_login': 'ubercraig',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/ubercraig',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/65249183?'},
#  25: {'id': 7971049,
#   'login': 'Mota-sem',
#   'display_login': 'Mota-sem',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/Mota-sem',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/7971049?'},
#  26: {'id': 49699333,
#   'login': 'dependabot[bot]',
#   'display_login': 'dependabot',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/dependabot[bot]',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#  27: {'id': 1505180,
#   'login': 'seattletimes',
#   'display_login': 'seattletimes',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/seattletimes',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/1505180?'},
#  28: {'id': 5833167,
#   'login': 'hujanais',
#   'display_login': 'hujanais',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/hujanais',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/5833167?'},
#  29: {'id': 43281546,
#   'login': 'drewsview34',
#   'display_login': 'drewsview34',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/drewsview34',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/43281546?'}}

# %%
pd.DataFrame(dict(data[column])).head()
# Out:
#                                                       0   \
# id                                              28953407
# login                                       pannalalaxmi
# display_login                               pannalalaxmi
# gravatar_id
# url            https://api.github.com/users/pannalalaxmi
#
#                                                  1   \
# id                                         66938086
# login                                       mmcvuur
# display_login                               mmcvuur
# gravatar_id
# url            https://api.github.com/users/mmcvuur
#
#                                                     2   \
# id                                            61796525
# login                                       tobias0709
# display_login                               tobias0709
# gravatar_id
# url            https://api.github.com/users/tobias0709
#
#                                                  3   \
# id                                          1496283
# login                                       mcg-web
# display_login                               mcg-web
# gravatar_id
# url            https://api.github.com/users/mcg-web
#
#                                                  4   \
# id                                         34471120
# login                                       RyazMax
# display_login                               RyazMax
# gravatar_id
# url            https://api.github.com/users/RyazMax
#
#                                                       5   \
# id                                               1505180
# login                                       seattletimes
# display_login                               seattletimes
# gravatar_id
# url            https://api.github.com/users/seattletimes
#
#                                                  6   \
# id                                            60754
# login                                       nebhale
# display_login                               nebhale
# gravatar_id
# url            https://api.github.com/users/nebhale
#
#                                                       7   \
# id                                               1505180
# login                                       seattletimes
# display_login                               seattletimes
# gravatar_id
# url            https://api.github.com/users/seattletimes
#
#                                                  8   \
# id                                            53469
# login                                       alfwatt
# display_login                               alfwatt
# gravatar_id
# url            https://api.github.com/users/alfwatt
#
#                                                  9   ...  \
# id                                         40006040  ...
# login                                       alexym1  ...
# display_login                               alexym1  ...
# gravatar_id                                          ...
# url            https://api.github.com/users/alexym1  ...
#
#                                                     20  \
# id                                             6749661
# login                                       test987987
# display_login                               test987987
# gravatar_id
# url            https://api.github.com/users/test987987
#
#                                                   21  \
# id                                           9154160
# login                                       krautcat
# display_login                               krautcat
# gravatar_id
# url            https://api.github.com/users/krautcat
#
#                                                        22  \
# id                                                7889724
# login                                       celinedurniak
# display_login                               celinedurniak
# gravatar_id
# url            https://api.github.com/users/celinedurniak
#
#                                                       23  \
# id                                               1505180
# login                                       seattletimes
# display_login                               seattletimes
# gravatar_id
# url            https://api.github.com/users/seattletimes
#
#                                                    24  \
# id                                           65249183
# login                                       ubercraig
# display_login                               ubercraig
# gravatar_id
# url            https://api.github.com/users/ubercraig
#
#                                                   25  \
# id                                           7971049
# login                                       Mota-sem
# display_login                               Mota-sem
# gravatar_id
# url            https://api.github.com/users/Mota-sem
#
#                                                          26  \
# id                                                 49699333
# login                                       dependabot[bot]
# display_login                                    dependabot
# gravatar_id
# url            https://api.github.com/users/dependabot[bot]
#
#                                                       27  \
# id                                               1505180
# login                                       seattletimes
# display_login                               seattletimes
# gravatar_id
# url            https://api.github.com/users/seattletimes
#
#                                                   28  \
# id                                           5833167
# login                                       hujanais
# display_login                               hujanais
# gravatar_id
# url            https://api.github.com/users/hujanais
#
#                                                      29
# id                                             43281546
# login                                       drewsview34
# display_login                               drewsview34
# gravatar_id
# url            https://api.github.com/users/drewsview34
#
# [5 rows x 30 columns]

# %%
pd.DataFrame(dict(data[column])).T.head()
# Out:
#          id         login display_login gravatar_id  \
# 0  28953407  pannalalaxmi  pannalalaxmi
# 1  66938086       mmcvuur       mmcvuur
# 2  61796525    tobias0709    tobias0709
# 3   1496283       mcg-web       mcg-web
# 4  34471120       RyazMax       RyazMax
#
#                                          url  \
# 0  https://api.github.com/users/pannalalaxmi
# 1       https://api.github.com/users/mmcvuur
# 2    https://api.github.com/users/tobias0709
# 3       https://api.github.com/users/mcg-web
# 4       https://api.github.com/users/RyazMax
#
#                                           avatar_url
# 0  https://avatars.githubusercontent.com/u/28953407?
# 1  https://avatars.githubusercontent.com/u/66938086?
# 2  https://avatars.githubusercontent.com/u/61796525?
# 3   https://avatars.githubusercontent.com/u/1496283?
# 4  https://avatars.githubusercontent.com/u/34471120?

# %% [markdown]
# ### 2.2 json_normalize

# %%
df_flattened = pd.json_normalize(json_data)

df_flattened.head()
# Out:
#             id         type  public            created_at  actor.id  \
# 0  12660240140  CreateEvent    True  2020-06-17T17:54:14Z  28953407
# 1  12660240125    PushEvent    True  2020-06-17T17:54:14Z  66938086
# 2  12660240124    PushEvent    True  2020-06-17T17:54:14Z  61796525
# 3  12660240133   WatchEvent    True  2020-06-17T17:54:14Z   1496283
# 4  12660240127  IssuesEvent    True  2020-06-17T17:54:14Z  34471120
#
#     actor.login actor.display_login actor.gravatar_id  \
# 0  pannalalaxmi        pannalalaxmi
# 1       mmcvuur             mmcvuur
# 2    tobias0709          tobias0709
# 3       mcg-web             mcg-web
# 4       RyazMax             RyazMax
#
#                                    actor.url  \
# 0  https://api.github.com/users/pannalalaxmi
# 1       https://api.github.com/users/mmcvuur
# 2    https://api.github.com/users/tobias0709
# 3       https://api.github.com/users/mcg-web
# 4       https://api.github.com/users/RyazMax
#
#                                     actor.avatar_url  ...  \
# 0  https://avatars.githubusercontent.com/u/28953407?  ...
# 1  https://avatars.githubusercontent.com/u/66938086?  ...
# 2  https://avatars.githubusercontent.com/u/61796525?  ...
# 3   https://avatars.githubusercontent.com/u/1496283?  ...
# 4  https://avatars.githubusercontent.com/u/34471120?  ...
#
#    payload.pull_request.merged_by payload.pull_request.comments  \
# 0                             NaN                           NaN
# 1                             NaN                           NaN
# 2                             NaN                           NaN
# 3                             NaN                           NaN
# 4                             NaN                           NaN
#
#   payload.pull_request.review_comments  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#   payload.pull_request.maintainer_can_modify payload.pull_request.commits  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
#
#   payload.pull_request.additions payload.pull_request.deletions  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
#
#   payload.pull_request.changed_files  payload.pull_request.head.repo.license  \
# 0                                NaN                                     NaN
# 1                                NaN                                     NaN
# 2                                NaN                                     NaN
# 3                                NaN                                     NaN
# 4                                NaN                                     NaN
#
#    payload.pull_request.base.repo.license
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
# [5 rows x 436 columns]

# %%
df_flattened.columns
# Out:
# Index(['id', 'type', 'public', 'created_at', 'actor.id', 'actor.login',
#        'actor.display_login', 'actor.gravatar_id', 'actor.url',
#        'actor.avatar_url',
#        ...
#        'payload.pull_request.merged_by', 'payload.pull_request.comments',
#        'payload.pull_request.review_comments',
#        'payload.pull_request.maintainer_can_modify',
#        'payload.pull_request.commits', 'payload.pull_request.additions',
#        'payload.pull_request.deletions', 'payload.pull_request.changed_files',
#        'payload.pull_request.head.repo.license',
#        'payload.pull_request.base.repo.license'],
#       dtype='object', length=436)

# %%
for col in df_flattened.columns:
    if 'commit' in col:
        print(col)
# Out:
# payload.commits
# payload.pull_request.merge_commit_sha
# payload.pull_request.commits_url
# payload.pull_request.head.repo.commits_url
# payload.pull_request.head.repo.git_commits_url
# payload.pull_request.base.repo.commits_url
# payload.pull_request.base.repo.git_commits_url
# payload.pull_request._links.commits.href
# payload.pull_request.commits

# %%
df_flattened['payload.commits']
# Out:
# 0                                                   NaN
# 1     [{'sha': 'b61a68009606ba8338e14519731af866f849...
# 2     [{'sha': '44f7803ccd1a2cf205088da54f2b670fbbb6...
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8     [{'sha': '04dfafc9b842b5ad236db5adb6b04d928bbb...
# 9     [{'sha': '0c7cf13d2c28283777c0050c3d8e4e823c98...
# 10                                                  NaN
# 11    [{'sha': 'b88fde8d80ad45c70a4dcbf8645cd3bf0fac...
# 12    [{'sha': 'd1788d76181002d138f9367e48d20aaaa5f8...
# 13                                                  NaN
# 14    [{'sha': '0cd891739e42636e60470e14cf22eff0fc8c...
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19    [{'sha': '603ad7d83d3f895f1bcdd4d1b57c6f84b45e...
# 20                                                  NaN
# 21                                                  NaN
# 22    [{'sha': '176255de0d4ae258c30fa5d5ca40947690b9...
# 23                                                  NaN
# 24    [{'sha': '33e1d33317692a2cae59001bc8e72d759398...
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28    [{'sha': 'be16980b4c4769e0ff7bf581cc9dbb4ee340...
# 29    [{'sha': '54b639ba56fb6af73bbef4e3cbb84501dd45...
# Name: payload.commits, dtype: object

# %%
pd.json_normalize(json_data, max_level=1)
# Out:
#              id               type  public            created_at  actor.id  \
# 0   12660240140        CreateEvent    True  2020-06-17T17:54:14Z  28953407
# 1   12660240125          PushEvent    True  2020-06-17T17:54:14Z  66938086
# 2   12660240124          PushEvent    True  2020-06-17T17:54:14Z  61796525
# 3   12660240133         WatchEvent    True  2020-06-17T17:54:14Z   1496283
# 4   12660240127        IssuesEvent    True  2020-06-17T17:54:14Z  34471120
# 5   12660240123        MemberEvent    True  2020-06-17T17:54:14Z   1505180
# 6   12660240119        CreateEvent    True  2020-06-17T17:54:14Z     60754
# 7   12660240109        MemberEvent    True  2020-06-17T17:54:14Z   1505180
# 8   12660240095          PushEvent    True  2020-06-17T17:54:14Z     53469
# 9   12660240094          PushEvent    True  2020-06-17T17:54:14Z  40006040
# 10  12660240090        MemberEvent    True  2020-06-17T17:54:14Z   1505180
# 11  12660240083          PushEvent    True  2020-06-17T17:54:14Z  43325903
# 12  12660240085          PushEvent    True  2020-06-17T17:54:14Z   1320020
# 13  12660240101  IssueCommentEvent    True  2020-06-17T17:54:14Z   1657309
# 14  12660240028          PushEvent    True  2020-06-17T17:54:14Z  42744223
# 15  12660240020   PullRequestEvent    True  2020-06-17T17:54:14Z  20636269
# 16  12660240055        MemberEvent    True  2020-06-17T17:54:14Z   1505180
# 17  12660240089        DeleteEvent    True  2020-06-17T17:54:14Z  29139614
# 18  12660240074        IssuesEvent    True  2020-06-17T17:54:14Z    307709
# 19  12660240073          PushEvent    True  2020-06-17T17:54:14Z  19895466
# 20  12660240077        DeleteEvent    True  2020-06-17T17:54:14Z   6749661
# 21  12660240075         WatchEvent    True  2020-06-17T17:54:14Z   9154160
# 22  12660240057          PushEvent    True  2020-06-17T17:54:14Z   7889724
# 23  12660240071        MemberEvent    True  2020-06-17T17:54:14Z   1505180
# 24  12660240059          PushEvent    True  2020-06-17T17:54:14Z  65249183
# 25  12660240066         WatchEvent    True  2020-06-17T17:54:14Z   7971049
# 26  12660240030   PullRequestEvent    True  2020-06-17T17:54:14Z  49699333
# 27  12660240051        MemberEvent    True  2020-06-17T17:54:14Z   1505180
# 28  12660240027          PushEvent    True  2020-06-17T17:54:14Z   5833167
# 29  12660240029          PushEvent    True  2020-06-17T17:54:14Z  43281546
#
#         actor.login actor.display_login actor.gravatar_id  \
# 0      pannalalaxmi        pannalalaxmi
# 1           mmcvuur             mmcvuur
# 2        tobias0709          tobias0709
# 3           mcg-web             mcg-web
# 4           RyazMax             RyazMax
# 5      seattletimes        seattletimes
# 6           nebhale             nebhale
# 7      seattletimes        seattletimes
# 8           alfwatt             alfwatt
# 9           alexym1             alexym1
# 10     seattletimes        seattletimes
# 11           bky-25              bky-25
# 12         starkej2            starkej2
# 13        stevehadd           stevehadd
# 14          KunyuHe             KunyuHe
# 15    chrisvsanchez       chrisvsanchez
# 16     seattletimes        seattletimes
# 17    renovate[bot]            renovate
# 18         gustafnk            gustafnk
# 19    MatheusMuriel       MatheusMuriel
# 20       test987987          test987987
# 21         krautcat            krautcat
# 22    celinedurniak       celinedurniak
# 23     seattletimes        seattletimes
# 24        ubercraig           ubercraig
# 25         Mota-sem            Mota-sem
# 26  dependabot[bot]          dependabot
# 27     seattletimes        seattletimes
# 28         hujanais            hujanais
# 29      drewsview34         drewsview34
#
#                                        actor.url  \
# 0      https://api.github.com/users/pannalalaxmi
# 1           https://api.github.com/users/mmcvuur
# 2        https://api.github.com/users/tobias0709
# 3           https://api.github.com/users/mcg-web
# 4           https://api.github.com/users/RyazMax
# 5      https://api.github.com/users/seattletimes
# 6           https://api.github.com/users/nebhale
# 7      https://api.github.com/users/seattletimes
# 8           https://api.github.com/users/alfwatt
# 9           https://api.github.com/users/alexym1
# 10     https://api.github.com/users/seattletimes
# 11           https://api.github.com/users/bky-25
# 12         https://api.github.com/users/starkej2
# 13        https://api.github.com/users/stevehadd
# 14          https://api.github.com/users/KunyuHe
# 15    https://api.github.com/users/chrisvsanchez
# 16     https://api.github.com/users/seattletimes
# 17    https://api.github.com/users/renovate[bot]
# 18         https://api.github.com/users/gustafnk
# 19    https://api.github.com/users/MatheusMuriel
# 20       https://api.github.com/users/test987987
# 21         https://api.github.com/users/krautcat
# 22    https://api.github.com/users/celinedurniak
# 23     https://api.github.com/users/seattletimes
# 24        https://api.github.com/users/ubercraig
# 25         https://api.github.com/users/Mota-sem
# 26  https://api.github.com/users/dependabot[bot]
# 27     https://api.github.com/users/seattletimes
# 28         https://api.github.com/users/hujanais
# 29      https://api.github.com/users/drewsview34
#
#                                      actor.avatar_url  ...  \
# 0   https://avatars.githubusercontent.com/u/28953407?  ...
# 1   https://avatars.githubusercontent.com/u/66938086?  ...
# 2   https://avatars.githubusercontent.com/u/61796525?  ...
# 3    https://avatars.githubusercontent.com/u/1496283?  ...
# 4   https://avatars.githubusercontent.com/u/34471120?  ...
# 5    https://avatars.githubusercontent.com/u/1505180?  ...
# 6      https://avatars.githubusercontent.com/u/60754?  ...
# 7    https://avatars.githubusercontent.com/u/1505180?  ...
# 8      https://avatars.githubusercontent.com/u/53469?  ...
# 9   https://avatars.githubusercontent.com/u/40006040?  ...
# 10   https://avatars.githubusercontent.com/u/1505180?  ...
# 11  https://avatars.githubusercontent.com/u/43325903?  ...
# 12   https://avatars.githubusercontent.com/u/1320020?  ...
# 13   https://avatars.githubusercontent.com/u/1657309?  ...
# 14  https://avatars.githubusercontent.com/u/42744223?  ...
# 15  https://avatars.githubusercontent.com/u/20636269?  ...
# 16   https://avatars.githubusercontent.com/u/1505180?  ...
# 17  https://avatars.githubusercontent.com/u/29139614?  ...
# 18    https://avatars.githubusercontent.com/u/307709?  ...
# 19  https://avatars.githubusercontent.com/u/19895466?  ...
# 20   https://avatars.githubusercontent.com/u/6749661?  ...
# 21   https://avatars.githubusercontent.com/u/9154160?  ...
# 22   https://avatars.githubusercontent.com/u/7889724?  ...
# 23   https://avatars.githubusercontent.com/u/1505180?  ...
# 24  https://avatars.githubusercontent.com/u/65249183?  ...
# 25   https://avatars.githubusercontent.com/u/7971049?  ...
# 26  https://avatars.githubusercontent.com/u/49699333?  ...
# 27   https://avatars.githubusercontent.com/u/1505180?  ...
# 28   https://avatars.githubusercontent.com/u/5833167?  ...
# 29  https://avatars.githubusercontent.com/u/43281546?  ...
#
#                                         payload.issue  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   {'url': 'https://api.github.com/repos/vovac12/...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  {'url': 'https://api.github.com/repos/Fracappo...
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18  {'url': 'https://api.github.com/repos/gustafnk...
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#                                        payload.member     org.id  \
# 0                                                 NaN        NaN
# 1                                                 NaN        NaN
# 2                                                 NaN        NaN
# 3                                                 NaN        NaN
# 4                                                 NaN        NaN
# 5   {'login': 'mhardy2', 'id': 20050574, 'node_id'...  1505180.0
# 6                                                 NaN   621746.0
# 7   {'login': 'mhardy2', 'id': 20050574, 'node_id'...  1505180.0
# 8                                                 NaN   600935.0
# 9                                                 NaN        NaN
# 10  {'login': 'mhardy2', 'id': 20050574, 'node_id'...  1505180.0
# 11                                                NaN        NaN
# 12                                                NaN        NaN
# 13                                                NaN        NaN
# 14                                                NaN        NaN
# 15                                                NaN  8825476.0
# 16  {'login': 'mhardy2', 'id': 20050574, 'node_id'...  1505180.0
# 17                                                NaN        NaN
# 18                                                NaN        NaN
# 19                                                NaN        NaN
# 20                                                NaN        NaN
# 21                                                NaN        NaN
# 22                                                NaN        NaN
# 23  {'login': 'mhardy2', 'id': 20050574, 'node_id'...  1505180.0
# 24                                                NaN        NaN
# 25                                                NaN        NaN
# 26                                                NaN        NaN
# 27  {'login': 'mhardy2', 'id': 20050574, 'node_id'...  1505180.0
# 28                                                NaN        NaN
# 29                                                NaN        NaN
#
#             org.login org.gravatar_id  \
# 0                 NaN             NaN
# 1                 NaN             NaN
# 2                 NaN             NaN
# 3                 NaN             NaN
# 4                 NaN             NaN
# 5        seattletimes
# 6        cloudfoundry
# 7        seattletimes
# 8              mapbox
# 9                 NaN             NaN
# 10       seattletimes
# 11                NaN             NaN
# 12                NaN             NaN
# 13                NaN             NaN
# 14                NaN             NaN
# 15  learn-co-students
# 16       seattletimes
# 17                NaN             NaN
# 18                NaN             NaN
# 19                NaN             NaN
# 20                NaN             NaN
# 21                NaN             NaN
# 22                NaN             NaN
# 23       seattletimes
# 24                NaN             NaN
# 25                NaN             NaN
# 26                NaN             NaN
# 27       seattletimes
# 28                NaN             NaN
# 29                NaN             NaN
#
#                                           org.url  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# 5        https://api.github.com/orgs/seattletimes
# 6        https://api.github.com/orgs/cloudfoundry
# 7        https://api.github.com/orgs/seattletimes
# 8              https://api.github.com/orgs/mapbox
# 9                                             NaN
# 10       https://api.github.com/orgs/seattletimes
# 11                                            NaN
# 12                                            NaN
# 13                                            NaN
# 14                                            NaN
# 15  https://api.github.com/orgs/learn-co-students
# 16       https://api.github.com/orgs/seattletimes
# 17                                            NaN
# 18                                            NaN
# 19                                            NaN
# 20                                            NaN
# 21                                            NaN
# 22                                            NaN
# 23       https://api.github.com/orgs/seattletimes
# 24                                            NaN
# 25                                            NaN
# 26                                            NaN
# 27       https://api.github.com/orgs/seattletimes
# 28                                            NaN
# 29                                            NaN
#
#                                       org.avatar_url  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5   https://avatars.githubusercontent.com/u/1505180?
# 6    https://avatars.githubusercontent.com/u/621746?
# 7   https://avatars.githubusercontent.com/u/1505180?
# 8    https://avatars.githubusercontent.com/u/600935?
# 9                                                NaN
# 10  https://avatars.githubusercontent.com/u/1505180?
# 11                                               NaN
# 12                                               NaN
# 13                                               NaN
# 14                                               NaN
# 15  https://avatars.githubusercontent.com/u/8825476?
# 16  https://avatars.githubusercontent.com/u/1505180?
# 17                                               NaN
# 18                                               NaN
# 19                                               NaN
# 20                                               NaN
# 21                                               NaN
# 22                                               NaN
# 23  https://avatars.githubusercontent.com/u/1505180?
# 24                                               NaN
# 25                                               NaN
# 26                                               NaN
# 27  https://avatars.githubusercontent.com/u/1505180?
# 28                                               NaN
# 29                                               NaN
#
#                                       payload.comment  payload.number  \
# 0                                                 NaN             NaN
# 1                                                 NaN             NaN
# 2                                                 NaN             NaN
# 3                                                 NaN             NaN
# 4                                                 NaN             NaN
# 5                                                 NaN             NaN
# 6                                                 NaN             NaN
# 7                                                 NaN             NaN
# 8                                                 NaN             NaN
# 9                                                 NaN             NaN
# 10                                                NaN             NaN
# 11                                                NaN             NaN
# 12                                                NaN             NaN
# 13  {'url': 'https://api.github.com/repos/Fracappo...             NaN
# 14                                                NaN             NaN
# 15                                                NaN             7.0
# 16                                                NaN             NaN
# 17                                                NaN             NaN
# 18                                                NaN             NaN
# 19                                                NaN             NaN
# 20                                                NaN             NaN
# 21                                                NaN             NaN
# 22                                                NaN             NaN
# 23                                                NaN             NaN
# 24                                                NaN             NaN
# 25                                                NaN             NaN
# 26                                                NaN             1.0
# 27                                                NaN             NaN
# 28                                                NaN             NaN
# 29                                                NaN             NaN
#
#                                  payload.pull_request
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  {'url': 'https://api.github.com/repos/learn-co...
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26  {'url': 'https://api.github.com/repos/Kozgor/K...
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
# [30 rows x 35 columns]

# %% [markdown]
# <div style="padding-top: 25px; float: right">
#     <div>
#         <i>&nbsp;&nbsp;© Copyright by</i>
#     </div>
#     <div>
#         <a href="https://whiteboxml.com">
#             <img src="https://whiteboxml.com/static/img/logo/black_bg_white.svg" width="125">
#         </a>
#     </div>
# </div>
