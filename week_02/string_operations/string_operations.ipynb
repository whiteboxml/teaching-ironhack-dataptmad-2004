# %% [markdown]
# <div style="float:right; padding-top: 15px; padding-right: 15px">
#     <div>
#         <a href="https://whiteboxml.com">
#             <img src="https://whiteboxml.com/static/img/logo/black_bg_white.svg" width="250">
#         </a>
#     </div>
# </div>

# %% [markdown]
# # String Operations

# %% [markdown]
# ## Common operations

# %%
# operator overload
print('Hello' + 'World')

# %%
print('Hello ' * 8)

# %%
a = 'Hello'
b = 'dog'

# forget about this
print(a + ' a ' + 'beautiful' + ' ' + b)
print('{} beautiful {} why {}'.format(a, b, a))
print('{0} beautiful {1} why {0}'.format(a, b))

# this is cream -> string interpolation
print(f'{a} beautiful {b}')

# %%
x = 'Happy'
y = 'Puppies'
z = [x,y,x]

print(z)
print(' '.join(z))
print('hello'.join(z))

# %%
mystring = ''
for i in z:
    mystring += i + ' '
    
print(mystring[:-1])
print(mystring.strip())

# %%
print(len(['automobile']))
print(len('automobile'))

# %% [markdown]
# ### Slicing

# %%
list(range(1,10))

# %%
list(range(1,10,4))

# %%
word = 'automobile'

print(word[0])
print(word[5])
print(word[-1])
print(word[-4])
print(word[0:4])
print(word[:4])
print(word[4:])

# i:f:s -> i first index, f last index, s step
print(word[0:4:3])
print(word[-3:len(word):2])

## TODO
# turn the string word using slicing
# expected result: elibomotua
print(word[len(word)::-1])
print(word[::-1])
print(word[:])

# %%
a = 'They ate the mystery meat. It tasted like chicken.'

# check the splitter is not included
print(a.split())
print(a.split(' '))
print(a.split('.'))
print(a.split('m'))
print(a.split('meat'))

# %%
# list comprehension
[char for char in a]

# %%
my_list = []

for char in a:
    my_list.append(char)
    
my_list

# %%
b = 'There is no business like show business.'

print(b.startswith('T'))
print(b.startswith('There'))
# python is case sensitive
print(b.startswith('there'))

print(b.endswith('.'))
print(b.endswith('business.'))
print(b.endswith('Business.'))

# %%
print('like' in b)
print('business' in b)
print('Business' in b)

# %%
c = 'shE HaD a maRveLoUs aSsoRtmeNt of PUPPETS. but helLo'

print(c.lower())
print(c.upper())
print(c.capitalize())
print(c.title())

# %%
d = '   I have a tendency to leave       trailing spaces.      '

print(d.strip())
print(d.lstrip())
print(d.rstrip())

print(len(d.strip()))
print(len(d.lstrip()))
print(len(d.rstrip()))

# %%
e = 'I thought       the movie    was wonderful!   '

print(e.replace('wonderful', 'horrible'))
print(e.replace('wonderful', 'just OK'))
print(e.replace('o', 'laksjdflñkjasñdl'))
print(e.replace(' ', ''))

# %%
e = e.replace('wonderful', 'horrible')

e

# %%
e.split()

# %%
' '.join(e.split())

# %% [markdown]
# ## Regex Introduction

# %% [markdown]
# Regular expressions allow us to perform different types of pattern matching on text in order to arrive at the result we want

# %%
import re

# %% [markdown]
# - search: Returns the first instance of an expression in a string
# - findall: Finds all instances of an expression in a string and returns them as a list
# - split: Splits a string based on a specified delimiter
# - sub: Substitutes a string/substring with another

# %%
text = 'My neighbor, Mr Rogers, Has 35 dogs.'

re.findall('nei', text)
# Out:
# ['nei']

# %%
re.search('[.]', text)
# Out:
# <re.Match object; span=(35, 36), match='.'>

# %%
re.findall('.', text)
# Out:
# ['M', 'y', ' ', 'n', 'e', 'i', 'g', 'h', 'b', 'o', 'r', ',', ' ', 'M', 'r', ' ', 'R', 'o', 'g', 'e', 'r', 's', ',', ' ', 'H', 'a', 's', ' ', '3', '5', ' ', 'd', 'o', 'g', 's', '.']

# %%
len(text)
# Out:
# 36

# %%
text[35:36]
# Out:
# '.'

# %%
text[-1]
# Out:
# '.'

# %%
re.search('[nei ]', text)
# Out:
# <re.Match object; span=(2, 3), match=' '>

# %%
re.findall('[nei ]', text)
# Out:
# [' ', 'n', 'e', 'i', ' ', ' ', 'e', ' ', ' ', ' ']

# %%
my_var = re.search('[mn]', text)

my_var
# Out:
# <re.Match object; span=(3, 4), match='n'>

# %%
# use dir to search for methods or attributes
dir(my_var)
# Out:
# ['__class__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'end',
#  'endpos',
#  'expand',
#  'group',
#  'groupdict',
#  'groups',
#  'lastgroup',
#  'lastindex',
#  'pos',
#  're',
#  'regs',
#  'span',
#  'start',
#  'string']

# %%
print(my_var.span())
print(my_var.start())
print(my_var.string)
# Out:
# (3, 4)
# 3
# My neighbor, Mr Rogers, Has 35 dogs.

# %%
re.findall('[mn]', text)
# Out:
# ['n']

# %% [markdown]
# Patterns:
#
# - [a-z]: Any lowercase letter between a and z.
# - [A-Z]: Any uppercase letter between A and Z.
# - [0-9]: Any numeric character between 0 and 9.

# %%
text = 'My neighbor, Mr Rogers, Has 35 ñogs.'

# %%
re.findall('[a-z]', text)
# Out:
# ['y',
#  'n',
#  'e',
#  'i',
#  'g',
#  'h',
#  'b',
#  'o',
#  'r',
#  'r',
#  'o',
#  'g',
#  'e',
#  'r',
#  's',
#  'a',
#  's',
#  'o',
#  'g',
#  's']

# %%
re.findall('[^a-z]', text)
# Out:
# ['M',
#  ' ',
#  ',',
#  ' ',
#  'M',
#  ' ',
#  'R',
#  ',',
#  ' ',
#  'H',
#  ' ',
#  '3',
#  '5',
#  ' ',
#  'ñ',
#  '.']

# %%
re.findall('[a-zA-Z]', text)
# Out:
# ['M',
#  'y',
#  'n',
#  'e',
#  'i',
#  'g',
#  'h',
#  'b',
#  'o',
#  'r',
#  'M',
#  'r',
#  'R',
#  'o',
#  'g',
#  'e',
#  'r',
#  's',
#  'H',
#  'a',
#  's',
#  'o',
#  'g',
#  's']

# %%
re.findall('[a-zA-Z ]', text)
# Out:
# ['M',
#  'y',
#  ' ',
#  'n',
#  'e',
#  'i',
#  'g',
#  'h',
#  'b',
#  'o',
#  'r',
#  ' ',
#  'M',
#  'r',
#  ' ',
#  'R',
#  'o',
#  'g',
#  'e',
#  'r',
#  's',
#  ' ',
#  'H',
#  'a',
#  's',
#  ' ',
#  ' ',
#  'o',
#  'g',
#  's']

# %% [markdown]
# Pattern shortcuts:
#
# - \w: Any alphanumeric character.
# - \W: Any non-alphanumeric character.
# - \d: Any numeric character.
# - \D: Any non-numeric character.
# - \s: Any whitespace characters.
# - \S: Any non-whitespace characters.
# - .: Any character except newline (\n).

# %%
re.findall('[\d]', text)
# Out:
# ['3', '5']

# %%
re.findall('[\w]', text)
# Out:
# ['M',
#  'y',
#  'n',
#  'e',
#  'i',
#  'g',
#  'h',
#  'b',
#  'o',
#  'r',
#  'M',
#  'r',
#  'R',
#  'o',
#  'g',
#  'e',
#  'r',
#  's',
#  'H',
#  'a',
#  's',
#  '3',
#  '5',
#  'ñ',
#  'o',
#  'g',
#  's']

# %%
re.findall('[\S]', text)
# Out:
# ['M',
#  'y',
#  'n',
#  'e',
#  'i',
#  'g',
#  'h',
#  'b',
#  'o',
#  'r',
#  ',',
#  'M',
#  'r',
#  'R',
#  'o',
#  'g',
#  'e',
#  'r',
#  's',
#  ',',
#  'H',
#  'a',
#  's',
#  '3',
#  '5',
#  'ñ',
#  'o',
#  'g',
#  's',
#  '.']

# %%
text.split(', ')
# Out:
# ['My neighbor', 'Mr Rogers', 'Has 35 ñogs.']

# %%
re.split(', ', text)
# Out:
# ['My neighbor', 'Mr Rogers', 'Has 35 ñogs.']

# %%
print(text.split('[0-9]'))
print(re.split('[0-9]', text))
print(re.split('[0-9]+', text))
# Out:
# ['My neighbor, Mr Rogers, Has 35 dogs.']
# ['My neighbor, Mr Rogers, Has ', '', ' dogs.']
# ['My neighbor, Mr Rogers, Has ', ' dogs.']

# %%
print(re.sub('[0-9]', '100', text))
print(re.sub('[0-9]{2}', '100', text))
print(re.sub('[0-9]{3}', '100', text))
print(re.sub('[0-9]+', '100', text))
# Out:
# My neighbor, Mr Rogers, Has 100100 dogs.
# My neighbor, Mr Rogers, Has 100 dogs.
# My neighbor, Mr Rogers, Has 35 dogs.
# My neighbor, Mr Rogers, Has 100 dogs.

# %%
text +=  'and 927834782634756294659234 cats'

print(text)
print(re.sub('[0-9]+', '100', text))
# Out:
# My neighbor, Mr Rogers, Has 35 dogs.and 927834782634756294659234 catsand 927834782634756294659234 catsand 927834782634756294659234 cats
# My neighbor, Mr Rogers, Has 100 dogs.and 100 catsand 100 catsand 100 cats

# %%
re.sub('[a-z]{2}', '100', text)
# Out:
# 'My , Mr Rs, H 35 .d 927834782634756294659234 d 927834782634756294659234 d 927834782634756294659234 '

# %% [markdown]
# <div style="padding-top: 25px; float: right">
#     <div>
#         <i>&nbsp;&nbsp;© Copyright by</i>
#     </div>
#     <div>
#         <a href="https://whiteboxml.com">
#             <img src="https://whiteboxml.com/static/img/logo/black_bg_white.svg" width="125">
#         </a>
#     </div>
# </div>
