# %% [markdown]
# <div style="float:right; padding-top: 15px; padding-right: 15px">
#     <div>
#         <a href="https://whiteboxml.com">
#             <img src="https://whiteboxml.com/static/img/logo/black_bg_white.svg" width="250">
#         </a>
#     </div>
# </div>

# %% [markdown]
# # Web Scraping

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# Web scraping refers to the automatic extraction of information from a web page. This information is often a page's content, but it can also include information in the page's headers, links present on the page, or any other information embedded in the page's HTML. Because of this, scraping has become one of the most popular ways to extract data from the web.
#
# _"With basic knowledge of HTML and the help of a few Python libraries, you can obtain information from just about any page on the Internet"_

# %% [markdown]
# ## 2. Libraries

# %%
# for parsing html
# !pip install BeautifulSoup4
# Out:
# Requirement already satisfied: BeautifulSoup4 in /home/ubuntu/miniconda3/envs/ironhack_env/lib/python3.7/site-packages (4.9.1)
# Requirement already satisfied: soupsieve>1.2 in /home/ubuntu/miniconda3/envs/ironhack_env/lib/python3.7/site-packages (from BeautifulSoup4) (2.0.1)

# %%
# for beautiful soup parser
# !pip install lxml
# Out:
# Requirement already satisfied: lxml in /home/ubuntu/miniconda3/envs/ironhack_env/lib/python3.7/site-packages (4.5.1)

# %%
# for pandas read_html
# !pip install html5lib
# Out:
# Requirement already satisfied: html5lib in /home/ubuntu/miniconda3/envs/ironhack_env/lib/python3.7/site-packages (1.0.1)
# Requirement already satisfied: webencodings in /home/ubuntu/miniconda3/envs/ironhack_env/lib/python3.7/site-packages (from html5lib) (0.5.1)
# Requirement already satisfied: six>=1.9 in /home/ubuntu/miniconda3/envs/ironhack_env/lib/python3.7/site-packages (from html5lib) (1.14.0)

# %% [markdown]
# ## 2. Scraping a Simple Web Page

# %%
import requests

url = 'https://datatau.net'
html = requests.get(url).content
html[:5000]
# Out:
# b'\n\n<html lang="en">\n\n<head>\n\n    \n        <title>DataTau - Hacker News Clone - Data Science Newsboard</title>\n    \n\n    <link rel="canonical" href="https://datatau.net">\n\n    <!-- Global site tag (gtag.js) - Google Analytics -->\n<script async src="https://www.googletagmanager.com/gtag/js?id=UA-138960039-3"></script>\n<script>\n    window.dataLayer = window.dataLayer || [];\n\n    function gtag() {\n        dataLayer.push(arguments);\n    }\n\n    gtag(\'js\', new Date());\n\n    gtag(\'config\', \'UA-138960039-3\');\n</script>\n\n<!-- Google Tag Manager -->\n<script>(function (w, d, s, l, i) {\n    w[l] = w[l] || [];\n    w[l].push({\n        \'gtm.start\':\n            new Date().getTime(), event: \'gtm.js\'\n    });\n    var f = d.getElementsByTagName(s)[0],\n        j = d.createElement(s), dl = l != \'dataLayer\' ? \'&l=\' + l : \'\';\n    j.async = true;\n    j.src =\n        \'https://www.googletagmanager.com/gtm.js?id=\' + i + dl;\n    f.parentNode.insertBefore(j, f);\n})(window, document, \'script\', \'dataLayer\', \'GTM-5N66FM9\');</script>\n<!-- End Google Tag Manager -->\n    \n\n<meta charset="UTF-8">\n<meta name="description"\n      content="DataTau: Hacker News Clone - Data Science Newsboard">\n<meta name="keywords"\n      content="datatau, machine learning, data science, ai, artificial inteligence,\n       blog, forum, deep learning, newsboard">\n<meta name="viewport" content="width=device-width, initial-scale=1.0">\n\n\n\n<meta property="og:title" content="DataTau"/>\n<meta property="og:description" content="DataTau: Hacker News Clone - Data Science Newsboard"/>\n<meta property="og:type" content="website"/>\n<meta property="og:url" content="https://datatau.net"/>\n<meta property="og:site_name" content="https://datatau.net"/>\n<meta property="og:image" content="https://datatau.net/static/img/datatau.png"/>\n\n\n\n<meta name="twitter:card" content="summary">\n<meta name="twitter:url" content="https://datatau.net">\n<meta name="twitter:title" content="DataTau">\n<meta name="twitter:description" content="DataTau: Hacker News Clone - Data Science Newsboard"/>\n<meta name="twitter:image" content="https://datatau.net/static/img/datatau.png">\n<meta name="twitter:site" content="@TheGurusTeam">\n<meta name="twitter:creator" content="@TheGurusTeam">\n\n    \n\n<!-- Favicon -->\n<link rel="shortcut icon" href="/static/img/favicon.ico"/>\n\n<!-- custom landing page stylesheets -->\n<link rel="stylesheet" href="/static/css/style.css"/>\n\n\n</head>\n\n<body>\n\n<!-- Google Tag Manager (noscript) -->\n<noscript>\n    <iframe src="https://www.googletagmanager.com/ns.html?id=GTM-5N66FM9"\n            height="0" width="0" style="display:none;visibility:hidden"></iframe>\n</noscript>\n<!-- End Google Tag Manager (noscript) -->\n\n<div class="center">\n    <table bgcolor="#f6f6ef" border="0" cellpadding="0" cellspacing="0" id="hnmain" width="85%">\n        <tr>\n            <td bgcolor="#00b4b4">\n                <table border="0" cellpadding="0" cellspacing="0" style="padding:2px" width="100%">\n                    <tr>\n                        <td style="width:18px;padding-right:4px">\n                            <a href="/">\n                                <img alt="DataTau logo"\n                                     height="18" src="/static/img/datatau.png"\n                                     style="border:1px white solid;"\n                                     width="18">\n                            </a>\n                        </td>\n                        <td style="line-height:12pt; height:10px;">\n              <span class="pagetop">\n                    <h1 class="hnname"><a href="/">DataTau</a></h1>\n\n                    <a href="/new">new</a> |\n                    <a href="/ask">ask</a> |\n                    <a href="/show">show</a> |\n                    <a href="/submit">submit</a>\n              </span>\n                        </td>\n                        <td style="text-align:right;padding ...

# %% [markdown]
# ### 2.1 Beautiful Soup

# %%
from bs4 import BeautifulSoup

# lxml is the parsing module
soup = BeautifulSoup(html, 'lxml')
table = soup.find_all('table', {'class':'itemlist'})[0]

table
# Out:
# <table border="0" cellpadding="0" cellspacing="0" class="itemlist">
# <!-- repeat this block n times-->
# <tr class="athing" id="2117">
# <td align="right" class="title" valign="top"><span class="rank">1.</span>
# </td>
# <td class="votelinks" valign="top">
# <div class="center">
# <a id="up_2117" onclick="upvotePost(this)" style="cursor: pointer">
# <div class="votearrow" title="upvote"></div>
# </a>
# </div>
# </td>
# <td class="title">
# <a class="storylink" href="https://insights.ai-jobs.net/we-launched-jobmarks/" id="title_2117" title="ai-jobs.net now with jobmarks for AI/ML/DS jobs">ai-jobs.net now with jobmarks for AI/ML/DS jobs</a>
# <span class="sitebit comhead"> (<a href="/site/ai-jobs.net"><span class="sitestr">ai-jobs.net</span></a>)</span>
# </td>
# </tr>
# <tr>
# <td colspan="2"></td>
# <td class="subtext">
# <span class="score" id="score_2117">
#         2 points</span> by
#       <a class="hnuser" href="/profile/85">pat</a>
# <a class="age" href="/post/2117">1 days ago</a> |
#       <a href="/post/2117">
#
#           discuss
#
#       </a>
# </td>
# </tr>
# <tr class="spacer" style="height:5px"></tr>
# <tr class="athing" id="2097">
# <td align="right" class="title" valign="top"><span class="rank">2.</span>
# </td>
# <td class="votelinks" valign="top">
# <div class="center">
# <a id="up_2097" onclick="upvotePost(this)" style="cursor: pointer">
# <div class="votearrow" title="upvote"></div>
# </a>
# </div>
# </td>
# <td class="title">
# <a class="storylink" href="https://medium.com/datatau/the-online-courses-you-must-take-to-be-a-better-data-scientist-36a06016c819?source=friends_link&amp;sk=fabbe6121b190ff57d9927228f98df91" id="title_2097" title="📚 The online courses you must take to be a better Data Scientist">📚 The online courses you must take to be a better Data Scientist</a>
# <span class="sitebit comhead"> (<a href="/site/medium.com"><span class="sitestr">medium.com</span></a>)</span>
# </td>
# </tr>
# <tr>
# <td colspan="2"></td>
# <td class="subtext">
# <span class="score" id="score_2097">
#         4 points</span> by
#       <a class="hnuser" href="/profile/1">thegurus</a>
# <a class="age" href="/post/2097">3 days ago</a> |
#       <a href="/post/2097">
#
#           discuss
#
#       </a>
# </td>
# </tr>
# <tr class="spacer" style="height:5px"></tr>
# <tr class="athing" id="2094">
# <td align="right" class="title" valign="top"><span class="rank">3.</span>
# </td>
# <td class="votelinks" valign="top">
# <div class="center">
# <a id="up_2094" onclick="upvotePost(this)" style="cursor: pointer">
# <div class="votearrow" title="upvote"></div>
# </a>
# </div>
# </td>
# <td class="title">
# <a class="storylink" href="https://medium.com/acing-ai/how-to-build-fair-ml-models-cd93bd44c661" id="title_2094" title="How to build fair ML models?">How to build fair ML models?</a>
# <span class="sitebit comhead"> (<a href="/site/medium.com"><span class="sitestr">medium.com</span></a>)</span>
# </td>
# </tr>
# <tr>
# <td colspan="2"></td>
# <td class="subtext">
# <span class="score" id="score_2094">
#         3 points</span> by
#       <a class="hnuser" href="/profile/624">acingai</a>
# <a class="age" href="/post/2094">3 days ago</a> |
#       <a href="/post/2094">
#
#           discuss
#
#       </a>
# </td>
# </tr>
# <tr class="spacer" style="height:5px"></tr>
# <tr class="athing" id="2082">
# <td align="right" class="title" valign="top"><span class="rank">4.</span>
# </td>
# <td class="votelinks" valign="top">
# <div class="center">
# <a id="up_2082" onclick="upvotePost(this)" style="cursor: pointer">
# <div class="votearrow" title="upvote"></div>
# </a>
# </div>
# </td>
# <td class="title">
# <a class="storylink" href="https://nlp-summit.johnsnowlabs.com/" id="title_2082" title="Join the NLP Summit for FREE">Join the NLP Summit for FREE</a>
# <span class="sitebit comhead"> (<a href="/site/johnsnowlabs.com"><span class="sitestr">johnsnowlabs.com</span></a>)</span>
# </td>
# </tr>
# <tr>
# <td colspan="2"></td>
# <td class="subtext">
# <span class="score" id="score_2082">
#         6 points</span> by
#       <a class="hnuser" href="/profile/609">dsselevate</a>
# <a class="age" href="/post/2082">10 days ago</a> |
#       <a href="/post/2082">
#
#           discuss
#
#       </a>
# </td>
# </tr>
# <tr class="spacer" style="height:5px"></tr>
# <tr class="athing" id="2073">
# <td align="right" class="title" valign="top"><span class="rank">5.</span>
# </td>
# <td class="votelinks" valign="top">
# <div class="center">
# <a id="up_2073" onclick="upvotePost(this)" style="cursor: pointer">
# <div class="votearrow" title="upvote"></div>
# </a>
# </div>
# </td>
# <td class="title">
# <a class="storylink" href="https://dsremote.work/" id="title_2073" title="Find remote work in Data Science">Find remote work in Data Science</a>
# <span class="sitebit comhead"> (<a href="/site/dsremote.work"><span class="sitestr">dsremote.work</span></a>)</span>
# </td>
# </tr>
# <tr>
# <td colspan="2"></td>
# <td class="subtext">
# <span class="score" id="score_2073">
#         7 points</span> by
#       <a class="hnuser" href="/profile/85">pat</a>
# <a class="age" href="/post/2073">12 days ago</a> |
#       <a href="/post/2073">
#
#           discuss
#
#       </a>
# </td>
# </tr>
# <tr class="spacer" style="height:5px"></tr>
# <tr class="athing" id="2087">
# <td align="right" class="title" valign="top"><span class="rank">6.</span>
# </td>
# <td class="votelinks" valign="top">
# <div class="center">
# <a id="up_2087" onclick="upvotePost(this)" style="cursor: pointer">
# <div class="votearrow" title="upvote"></div>
# </a>
# </div>
# </td>
# <td class="title">
# <a class="storylink" href="https://medium.com/acing-ai/tools-for-using-kubernetes-84d47a73ef2e" id="title_2087" title="What are the tools for a team of any level to realize a container architecture?">What are the tools for a team of any level to realize a container architecture?</a>
# <span class="sitebit comhead"> (<a href="/site/medium.com"><span class="sitestr">medium.com</span></a>)</span>
# </td>
# </tr>
# <tr>
# <td colspan="2"></td>
# <td class="subtext">
# <span class="score" id="score_2087">
#         4 points</span> by
#       <a class="hnuser" href="/profile/624">acingai</a>
# <a class="age" href="/post/2087">8 days ago</a> |
#       <a href="/post/2087">
#
#           discuss
#
#       </a>
# </td>
# </tr>
# <tr class="spacer" style="height:5px"></tr>
# <tr class="athing" id="2085">
# <td align="right" class="title" valign="top"><span class="rank">7.</span>
# </td>
# <td class="votelinks" valign="top">
# <div class="center">
# <a id="up_2085" onclick="upvotePost(this)" style="cursor: pointer">
# <div class="votearrow" title="upvote"></div>
# </a>
# </div>
# </td>
# <td class="title">
# <a class="storylink" href="https://info.datascience.salon/statistical-paradoxes-logical-fallacies-dont-believe-the-lies-your-data-tells" id="title_2085" title="Statistical Paradoxes &amp; Logical Fallacies: Don't Believe the Lies your Data Tells">Statistical Paradoxes &amp; Logical Fallacies: Don't Believe the Lies your Data Tells</a>
# <span class="sitebit comhead"> (<a href="/site/datascience.salon"><span class="sitestr">datascience.salon</span></a>)</span>
# </td>
# </tr>
# <tr>
# <td colspan="2"></td>
# <td class="subtext">
# <span class="score" id="score_2085">
#         4 points</span> by
#       <a class="hnuser" href="/profile/609">dsselevate</a>
# <a class="age" href="/post/2085">9 days ago</a> |
#       <a href="/post/2085">
#
#           discuss
#
#       </a>
# </td>
# </tr>
# <tr class="spacer" style="height:5px"></tr>
# <tr class="athing" id="2088">
# <td align="right" class="title" valign="top"><span class="rank">8.</span>
# </td>
# <td class="votelinks" valign="top">
# <div class="center">
# <a id="up_2088" onclick="upvotePost(this)" style="cursor: pointer">
# <div class="votearrow" title="upvote"></div>
# </a>
# </div>
# </td>
# <td class="title">
# <a class="storylink" href="https://www.interviewquery.com/blog-python-data-science-interview-questions/" id="title_2088" title="Python Data Science Interview Questions">Python Data Science Interview Questions</a>
# <span class="sitebit comhead"> (<a href="/site/interviewquery.com"><span class="sitestr">interviewquery.com</span></a>)</span>
# </td>
# </tr>
# <tr>
# <td colspan="2"></td>
# <td class="subtext">
# <span class="score" id="score_2088">
#         3 points</span> by
#       <a class="hnuser" href="/profile/135">data4lyfe</a>
# <a class="age" href="/post/2088">8 days ago</a> |
#       <a href="/post/2088">
#
#           discuss
#
#       </a>
# </td>
# </tr>
# <tr class="spacer" style="height:5px"></tr>
# <tr class="athing" id="2079">
# <td align="right" class="title" valign="top"><span class="rank">9.</span>
# </td>
# <td class="votelinks" valign="top">
# <div class="center">
# <a id="up_2079" onclick="upvotePost(this)" style="cursor: pointer">
# <div class="votearrow" title="upvote"></div>
# </a>
# </div>
# </td>
# <td class="title">
# <a class="storylink" href="https://medium.com/acing-ai/continuous-monitoring-for-data-projects-11fb1c00c7a4" id="title_2079" title="Continuous Monitoring for data projects">Continuous Monitoring for data projects</a>
# <span class="sitebit comhead"> (<a href="/site/medium.com"><span class="sitestr">medium.com</span></a>)</span>
# </td>
# </tr>
# <tr>
# <td colspan="2"></td>
# <td class="subtext">
# <span class="score" id="score_2079">
#         2 points</span> by
#       <a class="hnuser" href="/profile/624">acingai</a>
# <a class="age" href="/post/2079">10 days ago</a> |
#       <a href="/post/2079">
#
#           discuss
#
#       </a>
# </td>
# </tr>
# <tr class="spacer" style="height:5px"></tr>
# <tr class="athing" id="2071">
# <td align="right" class="title" valign="top"><span class="rank">10.</span>
# </td>
# <td class="votelinks" valign="top">
# <div class="center">
# <a id="up_2071" onclick="upvotePost(this)" style="cursor: pointer">
# <div class="votearrow" title="upvote"></div>
# </a>
# </div>
# </td>
# <td class="title">
# <a class="storylink" href="https://medium.com/@romanorac/pandas-data-analysis-series-b8cec5b38b22" id="title_2071" title="Pandas Data Analysis Series">Pandas Data Analysis Series</a>
# <span class="sitebit comhead"> (<a href="/site/medium.com"><span class="sitestr">medium.com</span></a>)</span>
# </td>
# </tr>
# <tr>
# <td colspan="2"></td>
# <td class="subtext">
# <span class="score" id="score_2071">
#         2 points</span> by
#       <a class="hnuser" href="/profile/275">hippohoppy</a>
# <a class="age" href="/post/2071">14 days ago</a> |
#       <a href="/post/2071">
#
#           discuss
#
#       </a>
# </td>
# </tr>
# <tr class="spacer" style="height:5px"></tr>
# <tr class="athing" id="2078">
# <td align="right" class="title" valign="top"><span class="rank">11.</span>
# </td>
# <td class="votelinks" valign="top">
# <div class="center">
# <a id="up_2078" onclick="upvotePost(this)" style="cursor: pointer">
# <div class="votearrow" title="upvote"></div>
# </a>
# </div>
# </td>
# <td class="title">
# <a class="storylink" href="https://www.kdnuggets.com/2020/06/dont-democratize-data-science.html" id="title_2078" title="Don't Democratize Data Science">Don't Democratize Data Science</a>
# <span class="sitebit comhead"> (<a href="/site/kdnuggets.com"><span class="sitestr">kdnuggets.com</span></a>)</span>
# </td>
# </tr>
# <tr>
# <td colspan="2"></td>
# <td class="subtext">
# <span class="score" id="score_2078">
#         1 point</span> by
#       <a class="hnuser" href="/profile/1">thegurus</a>
# <a class="age" href="/post/2078">11 days ago</a> |
#       <a href="/post/2078">
#
#           discuss
#
#       </a>
# </td>
# </tr>
# <tr class="spacer" style="height:5px"></tr>
# <tr class="athing" id="2086">
# <td align="right" class="title" valign="top"><span class="rank">12.</span>
# </td>
# <td class="votelinks" valign="top">
# <div class="center">
# <a id="up_2086" onclick="upvotePost(this)" style="cursor: pointer">
# <div class="votearrow" title="upvote"></div>
# </a>
# </div>
# </td>
# <td class="title">
# <a class="storylink" href="https://www.deepflow.ai/what-are-activation-functions/" id="title_2086" title="Deep Learning: What are activation functions? An overview using Python">Deep Learning: What are activation functions? An overview using Python</a>
# <span class="sitebit comhead"> (<a href="/site/deepflow.ai"><span class="sitestr">deepflow.ai</span></a>)</span>
# </td>
# </tr>
# <tr>
# <td colspan="2"></td>
# <td class="subtext">
# <span class="score" id="score_2086">
#         1 point</span> by
#       <a class="hnuser" href="/profile/659">fabdrnd</a>
# <a class="age" href="/post/2086">9 days ago</a> |
#       <a href="/post/2086">
#
#           discuss
#
#       </a>
# </td>
# </tr>
# <tr class="spacer" style="height:5px"></tr>
# <tr class="athing" id="2074">
# <td align="right" class="title" valign="top"><span class="rank">13.</span>
# </td>
# <td class="votelinks" valign="top">
# <div class="center">
# <a id="up_2074" onclick="upvotePost(this)" style="cursor: pointer">
# <div class="votearrow" title="upvote"></div>
# </a>
# </div>
# </td>
# <td class="title">
# <a class="storylink" href="https://evojam.com/technology-blog/2020/5/18/the-secret-of-painless-websocket-tests-with-spock-framework" id="title_2074" title="The Secret of Painless WebSocket Tests with Spock Framework">The Secret of Painless WebSocket Tests with Spock Framework</a>
# <span class="sitebit comhead"> (<a href="/site/evojam.com"><span class="sitestr">evojam.com</span></a>)</span>
# </td>
# </tr>
# <tr>
# <td colspan="2"></td>
# <td class="subtext">
# <span class="score" id="score_2074">
#         1 point</span> by
#       <a class="hnuser" href="/profile/717">zmakowska</a>
# <a class="age" href="/post/2074">12 days ago</a> |
#       <a href="/post/2074">
#
#           discuss
#
#       </a>
# </td>
# </tr>
# <tr class="spacer" style="height:5px"></tr>
# <tr class="athing" id="2081">
# <td align="right" class="title" valign="top"><span class="rank">14.</span>
# </td>
# <td class="votelinks" valign="top">
# <div class="center">
# <a id="up_2081" onclick="upvotePost(this)" style="cursor: pointer">
# <div class="votearrow" title="upvote"></div>
# </a>
# </div>
# </td>
# <td class="title">
# <a class="storylink" href="https://youtu.be/QsIcEqGriGg" id="title_2081" title="Funnel Transformer Explained">Funnel Transformer Explained</a>
# <span class="sitebit comhead"> (<a href="/site/youtu.be"><span class="sitestr">youtu.be</span></a>)</span>
# </td>
# </tr>
# <tr>
# <td colspan="2"></td>
# <td class="subtext">
# <span class="score" id="score_2081">
#         1 point</span> by
#       <a class="hnuser" href="/profile/345">henryailabs</a>
# <a class="age" href="/post/2081">10 days ago</a> |
#       <a href="/post/2081">
#
#           discuss
#
#       </a>
# </td>
# </tr>
# <tr class="spacer" style="height:5px"></tr>
# <tr class="athing" id="2083">
# <td align="right" class="title" valign="top"><span class="rank">15.</span>
# </td>
# <td class="votelinks" valign="top">
# <div class="center">
# <a id="up_2083" onclick="upvotePost(this)" style="cursor: pointer">
# <div class="votearrow" title="upvote"></div>
# </a>
# </div>
# </td>
# <td class="title">
# <a class="storylink" href="https://www.interviewquery.com/blog-data-science-coaching/" id="title_2083" title="Why Data Science Coaching?">Why Data Science Coaching?</a>
# <span class="sitebit comhead"> (<a href="/site/interviewquery.com"><span class="sitestr">interviewquery.com</span></a>)</span>
# </td>
# </tr>
# <tr>
# <td colspan="2"></td>
# <td class="subtext">
# <span class="score" id="score_2083">
#         1 point</span> by
#       <a class="hnuser" href="/profile/135">data4lyfe</a>
# <a class="age" href="/post/2083">10 days ago</a> |
#       <a href="/post/2083">
#
#           discuss
#
#       </a>
# </td>
# </tr>
# <tr class="spacer" style="height:5px"></tr>
# <tr class="athing" id="2075">
# <td align="right" class="title" valign="top"><span class="rank">16.</span>
# </td>
# <td class="votelinks" valign="top">
# <div class="center">
# <a id="up_2075" onclick="upvotePost(this)" style="cursor: pointer">
# <div class="votearrow" title="upvote"></div>
# </a>
# </div>
# </td>
# <td class="title">
# <a class="storylink" href="https://towardsdatascience.com/how-to-become-a-data-scientist-from-software-developer-9ae868287fdd" id="title_2075" title="How to Become a Data Scientist from Software Developer">How to Become a Data Scientist from Software Developer</a>
# <span class="sitebit comhead"> (<a href="/site/towardsdatascience.com"><span class="sitestr">towardsdatascience.com</span></a>)</span>
# </td>
# </tr>
# <tr>
# <td colspan="2"></td>
# <td class="subtext">
# <span class="score" id="score_2075">
#         1 point</span> by
#       <a class="hnuser" href="/profile/718">balavenkatesh</a>
# <a class="age" href="/post/2075">11 days ago</a> |
#       <a href="/post/2075">
#
#           discuss
#
#       </a>
# </td>
# </tr>
# <tr class="spacer" style="height:5px"></tr>
# <tr class="athing" id="2076">
# <td align="right" class="title" valign="top"><span class="rank">17.</span>
# </td>
# <td class="votelinks" valign="top">
# <div class="center">
# <a id="up_2076" onclick="upvotePost(this)" style="cursor: pointer">
# <div class="votearrow" title="upvote"></div>
# </a>
# </div>
# </td>
# <td class="title">
# <a class="storylink" href="https://towardsdatascience.com/three-lines-code-to-implement-computer-vision-application-using-tensorflow-js-5a3a5e91f74a" id="title_2076" title="Three lines of code to implement a computer vision application using Tensorflow.js">Three lines of code to implement a computer vision application using Tensorflow.js</a>
# <span class="sitebit comhead"> (<a href="/site/towardsdatascience.com"><span class="sitestr">towardsdatascience.com</span></a>)</span>
# </td>
# </tr>
# <tr>
# <td colspan="2"></td>
# <td class="subtext">
# <span class="score" id="score_2076">
#         1 point</span> by
#       <a class="hnuser" href="/profile/718">balavenkatesh</a>
# <a class="age" href="/post/2076">11 days ago</a> |
#       <a href="/post/2076">
#
#           discuss
#
#       </a>
# </td>
# </tr>
# <tr class="spacer" style="height:5px"></tr>
# <tr class="athing" id="2077">
# <td align="right" class="title" valign="top"><span class="rank">18.</span>
# </td>
# <td class="votelinks" valign="top">
# <div class="center">
# <a id="up_2077" onclick="upvotePost(this)" style="cursor: pointer">
# <div class="votearrow" title="upvote"></div>
# </a>
# </div>
# </td>
# <td class="title">
# <a class="storylink" href="https://blog.usejournal.com/machine-learning-environment-setup-within-10min-515c34ee33f3" id="title_2077" title="Machine learning environment setup within 10min!!!">Machine learning environment setup within 10min!!!</a>
# <span class="sitebit comhead"> (<a href="/site/usejournal.com"><span class="sitestr">usejournal.com</span></a>)</span>
# </td>
# </tr>
# <tr>
# <td colspan="2"></td>
# <td class="subtext">
# <span class="score" id="score_2077">
#         1 point</span> by
#       <a class="hnuser" href="/profile/718">balavenkatesh</a>
# <a class="age" href="/post/2077">11 days ago</a> |
#       <a href="/post/2077">
#
#           discuss
#
#       </a>
# </td>
# </tr>
# <tr class="spacer" style="height:5px"></tr>
# <tr class="athing" id="2084">
# <td align="right" class="title" valign="top"><span class="rank">19.</span>
# </td>
# <td class="votelinks" valign="top">
# <div class="center">
# <a id="up_2084" onclick="upvotePost(this)" style="cursor: pointer">
# <div class="votearrow" title="upvote"></div>
# </a>
# </div>
# </td>
# <td class="title">
# <a class="storylink" href="https://www.kdnuggets.com/2020/05/automated-machine-learning-free-ebook.html" id="title_2084" title="Automated Machine Learning: The Free eBook">Automated Machine Learning: The Free eBook</a>
# <span class="sitebit comhead"> (<a href="/site/kdnuggets.com"><span class="sitestr">kdnuggets.com</span></a>)</span>
# </td>
# </tr>
# <tr>
# <td colspan="2"></td>
# <td class="subtext">
# <span class="score" id="score_2084">
#         1 point</span> by
#       <a class="hnuser" href="/profile/1">thegurus</a>
# <a class="age" href="/post/2084">10 days ago</a> |
#       <a href="/post/2084">
#
#           discuss
#
#       </a>
# </td>
# </tr>
# <tr class="spacer" style="height:5px"></tr>
# <tr class="athing" id="2089">
# <td align="right" class="title" valign="top"><span class="rank">20.</span>
# </td>
# <td class="votelinks" valign="top">
# <div class="center">
# <a id="up_2089" onclick="upvotePost(this)" style="cursor: pointer">
# <div class="votearrow" title="upvote"></div>
# </a>
# </div>
# </td>
# <td class="title">
# <a class="storylink" href="https://towardsdatascience.com/evolutions-in-data-science-ee596824d187" id="title_2089" title="Evolutions in data science">Evolutions in data science</a>
# <span class="sitebit comhead"> (<a href="/site/towardsdatascience.com"><span class="sitestr">towardsdatascience.com</span></a>)</span>
# </td>
# </tr>
# <tr>
# <td colspan="2"></td>
# <td class="subtext">
# <span class="score" id="score_2089">
#         1 point</span> by
#       <a class="hnuser" href="/profile/175">italosayan</a>
# <a class="age" href="/post/2089">6 days ago</a> |
#       <a href="/post/2089">
#
#           discuss
#
#       </a>
# </td>
# </tr>
# <tr class="spacer" style="height:5px"></tr>
# <tr class="athing" id="2092">
# <td align="right" class="title" valign="top"><span class="rank">21.</span>
# </td>
# <td class="votelinks" valign="top">
# <div class="center">
# <a id="up_2092" onclick="upvotePost(this)" style="cursor: pointer">
# <div class="votearrow" title="upvote"></div>
# </a>
# </div>
# </td>
# <td class="title">
# <a class="storylink" href="https://www.kdnuggets.com/2020/06/easy-speech-text-python.html" id="title_2092" title="Easy Speech-to-Text with Python">Easy Speech-to-Text with Python</a>
# <span class="sitebit comhead"> (<a href="/site/kdnuggets.com"><span class="sitestr">kdnuggets.com</span></a>)</span>
# </td>
# </tr>
# <tr>
# <td colspan="2"></td>
# <td class="subtext">
# <span class="score" id="score_2092">
#         1 point</span> by
#       <a class="hnuser" href="/profile/1">thegurus</a>
# <a class="age" href="/post/2092">4 days ago</a> |
#       <a href="/post/2092">
#
#           discuss
#
#       </a>
# </td>
# </tr>
# <tr class="spacer" style="height:5px"></tr>
# <tr class="athing" id="2114">
# <td align="right" class="title" valign="top"><span class="rank">22.</span>
# </td>
# <td class="votelinks" valign="top">
# <div class="center">
# <a id="up_2114" onclick="upvotePost(this)" style="cursor: pointer">
# <div class="votearrow" title="upvote"></div>
# </a>
# </div>
# </td>
# <td class="title">
# <a class="storylink" href="https://github.com/trekhleb/machine-learning-experiments/blob/master/assets/recipes_generation.en.md" id="title_2114" title="Generating cooking recipes using TensorFlow and LSTM Recurrent Neural Network: A step-by-step guide">Generating cooking recipes using TensorFlow and LSTM Recurrent Neural Network: A step-by-step guide</a>
# <span class="sitebit comhead"> (<a href="/site/github.com"><span class="sitestr">github.com</span></a>)</span>
# </td>
# </tr>
# <tr>
# <td colspan="2"></td>
# <td class="subtext">
# <span class="score" id="score_2114">
#         1 point</span> by
#       <a class="hnuser" href="/profile/670">trekhleb</a>
# <a class="age" href="/post/2114">1 days ago</a> |
#       <a href="/post/2114">
#
#           discuss
#
#       </a>
# </td>
# </tr>
# <tr class="spacer" style="height:5px"></tr>
# <tr class="athing" id="2095">
# <td align="right" class="title" valign="top"><span class="rank">23.</span>
# </td>
# <td class="votelinks" valign="top">
# <div class="center">
# <a id="up_2095" onclick="upvotePost(this)" style="cursor: pointer">
# <div class="votearrow" title="upvote"></div>
# </a>
# </div>
# </td>
# <td class="title">
# <a class="storylink" href="https://www.deepflow.ai/designing-trustworthy-ai/" id="title_2095" title="Explainable AI for the enterprise is about who owns AI projects in your company">Explainable AI for the enterprise is about who owns AI projects in your company</a>
# <span class="sitebit comhead"> (<a href="/site/deepflow.ai"><span class="sitestr">deepflow.ai</span></a>)</span>
# </td>
# </tr>
# <tr>
# <td colspan="2"></td>
# <td class="subtext">
# <span class="score" id="score_2095">
#         1 point</span> by
#       <a class="hnuser" href="/profile/659">fabdrnd</a>
# <a class="age" href="/post/2095">3 days ago</a> |
#       <a href="/post/2095">
#
#           discuss
#
#       </a>
# </td>
# </tr>
# <tr class="spacer" style="height:5px"></tr>
# <tr class="athing" id="2096">
# <td align="right" class="title" valign="top"><span class="rank">24.</span>
# </td>
# <td class="votelinks" valign="top">
# <div class="center">
# <a id="up_2096" onclick="upvotePost(this)" style="cursor: pointer">
# <div class="votearrow" title="upvote"></div>
# </a>
# </div>
# </td>
# <td class="title">
# <a class="storylink" href="https://www.kdnuggets.com/2020/06/start-statistics-all-over-again.html" id="title_2096" title="If you had to start statistics all over again, where would you start?">If you had to start statistics all over again, where would you start?</a>
# <span class="sitebit comhead"> (<a href="/site/kdnuggets.com"><span class="sitestr">kdnuggets.com</span></a>)</span>
# </td>
# </tr>
# <tr>
# <td colspan="2"></td>
# <td class="subtext">
# <span class="score" id="score_2096">
#         1 point</span> by
#       <a class="hnuser" href="/profile/1">thegurus</a>
# <a class="age" href="/post/2096">3 days ago</a> |
#       <a href="/post/2096">
#
#           discuss
#
#       </a>
# </td>
# </tr>
# <tr class="spacer" style="height:5px"></tr>
# <tr class="athing" id="2116">
# <td align="right" class="title" valign="top"><span class="rank">25.</span>
# </td>
# <td class="votelinks" valign="top">
# <div class="center">
# <a id="up_2116" onclick="upvotePost(this)" style="cursor: pointer">
# <div class="votearrow" title="upvote"></div>
# </a>
# </div>
# </td>
# <td class="title">
# <a class="storylink" href="https://www.linkedin.com/posts/bala-venkatesh-67964247_computervision-faceabrunlock-datascientists-activity-6679357168539566080-d-vW" id="title_2116" title="Lock &amp; Unlock Ubunto system using OpenCV">Lock &amp; Unlock Ubunto system using OpenCV</a>
# <span class="sitebit comhead"> (<a href="/site/linkedin.com"><span class="sitestr">linkedin.com</span></a>)</span>
# </td>
# </tr>
# <tr>
# <td colspan="2"></td>
# <td class="subtext">
# <span class="score" id="score_2116">
#         1 point</span> by
#       <a class="hnuser" href="/profile/718">balavenkatesh</a>
# <a class="age" href="/post/2116">1 days ago</a> |
#       <a href="/post/2116">
#
#           discuss
#
#       </a>
# </td>
# </tr>
# <tr class="spacer" style="height:5px"></tr>
# <tr class="athing" id="2098">
# <td align="right" class="title" valign="top"><span class="rank">26.</span>
# </td>
# <td class="votelinks" valign="top">
# <div class="center">
# <a id="up_2098" onclick="upvotePost(this)" style="cursor: pointer">
# <div class="votearrow" title="upvote"></div>
# </a>
# </div>
# </td>
# <td class="title">
# <a class="storylink" href="https://moffeckli.com.ng/16/06/2020/10-free-ways-to-make-money-for-the-unemployed-not-all-fancy-though/8369/reviews/" id="title_2098" title="10 Free Ways to Make Money For The Unemployed; Not All Fancy Though">10 Free Ways to Make Money For The Unemployed; Not All Fancy Though</a>
# <span class="sitebit comhead"> (<a href="/site/com.ng"><span class="sitestr">com.ng</span></a>)</span>
# </td>
# </tr>
# <tr>
# <td colspan="2"></td>
# <td class="subtext">
# <span class="score" id="score_2098">
#         1 point</span> by
#       <a class="hnuser" href="/profile/727">kennybbb</a>
# <a class="age" href="/post/2098">2 days ago</a> |
#       <a href="/post/2098">
#
#           discuss
#
#       </a>
# </td>
# </tr>
# <tr class="spacer" style="height:5px"></tr>
# <tr class="athing" id="2099">
# <td align="right" class="title" valign="top"><span class="rank">27.</span>
# </td>
# <td class="votelinks" valign="top">
# <div class="center">
# <a id="up_2099" onclick="upvotePost(this)" style="cursor: pointer">
# <div class="votearrow" title="upvote"></div>
# </a>
# </div>
# </td>
# <td class="title">
# <a class="storylink" href="https://moffeckli.com.ng/14/06/2020/make-money-in-nigeria-as-a-student-9-ways-to-invest-10-50k/8347/making-money-online/" id="title_2099" title="Make money in Nigeria as a student &amp; non student; invest #10-#50k now">Make money in Nigeria as a student &amp; non student; invest #10-#50k now</a>
# <span class="sitebit comhead"> (<a href="/site/com.ng"><span class="sitestr">com.ng</span></a>)</span>
# </td>
# </tr>
# <tr>
# <td colspan="2"></td>
# <td class="subtext">
# <span class="score" id="score_2099">
#         1 point</span> by
#       <a class="hnuser" href="/profile/727">kennybbb</a>
# <a class="age" href="/post/2099">2 days ago</a> |
#       <a href="/post/2099">
#
#           discuss
#
#       </a>
# </td>
# </tr>
# <tr class="spacer" style="height:5px"></tr>
# <tr class="athing" id="2100">
# <td align="right" class="title" valign="top"><span class="rank">28.</span>
# </td>
# <td class="votelinks" valign="top">
# <div class="center">
# <a id="up_2100" onclick="upvotePost(this)" style="cursor: pointer">
# <div class="votearrow" title="upvote"></div>
# </a>
# </div>
# </td>
# <td class="title">
# <a class="storylink" href="https://moffeckli.com.ng/17/06/2020/week-50-pool-fixtures-week-50-pool-results-uk-2019-2020/8373/sponsored-content/" id="title_2100" title="Week 50 Pool Fixtures, Week 50 Pool Results – UK 2019/2020">Week 50 Pool Fixtures, Week 50 Pool Results – UK 2019/2020</a>
# <span class="sitebit comhead"> (<a href="/site/com.ng"><span class="sitestr">com.ng</span></a>)</span>
# </td>
# </tr>
# <tr>
# <td colspan="2"></td>
# <td class="subtext">
# <span class="score" id="score_2100">
#         1 point</span> by
#       <a class="hnuser" href="/profile/727">kennybbb</a>
# <a class="age" href="/post/2100">2 days ago</a> |
#       <a href="/post/2100">
#
#           discuss
#
#       </a>
# </td>
# </tr>
# <tr class="spacer" style="height:5px"></tr>
# <tr class="athing" id="2101">
# <td align="right" class="title" valign="top"><span class="rank">29.</span>
# </td>
# <td class="votelinks" valign="top">
# <div class="center">
# <a id="up_2101" onclick="upvotePost(this)" style="cursor: pointer">
# <div class="votearrow" title="upvote"></div>
# </a>
# </div>
# </td>
# <td class="title">
# <a class="storylink" href="https://moffeckli.com.ng/17/06/2020/week-50-pool-result-classified-football-pools-fixtures-aussie-2020/8377/sponsored-content/" id="title_2101" title="Week 50 Pool Result; Classified Football Pools Fixtures – AUSSIE 2020">Week 50 Pool Result; Classified Football Pools Fixtures – AUSSIE 2020</a>
# <span class="sitebit comhead"> (<a href="/site/com.ng"><span class="sitestr">com.ng</span></a>)</span>
# </td>
# </tr>
# <tr>
# <td colspan="2"></td>
# <td class="subtext">
# <span class="score" id="score_2101">
#         1 point</span> by
#       <a class="hnuser" href="/profile/727">kennybbb</a>
# <a class="age" href="/post/2101">2 days ago</a> |
#       <a href="/post/2101">
#
#           discuss
#
#       </a>
# </td>
# </tr>
# <tr class="spacer" style="height:5px"></tr>
# <tr class="athing" id="2104">
# <td align="right" class="title" valign="top"><span class="rank">30.</span>
# </td>
# <td class="votelinks" valign="top">
# <div class="center">
# <a id="up_2104" onclick="upvotePost(this)" style="cursor: pointer">
# <div class="votearrow" title="upvote"></div>
# </a>
# </div>
# </td>
# <td class="title">
# <a class="storylink" href="https://moffeckli.com.ng/12/06/2020/sunbiz-forum-review-register-with-500-and-earn-5k-daily/8059/making-money-online/" id="title_2104" title="Sunbiz Forum Review; Register With #500 and Earn #5k Daily">Sunbiz Forum Review; Register With #500 and Earn #5k Daily</a>
# <span class="sitebit comhead"> (<a href="/site/com.ng"><span class="sitestr">com.ng</span></a>)</span>
# </td>
# </tr>
# <tr>
# <td colspan="2"></td>
# <td class="subtext">
# <span class="score" id="score_2104">
#         1 point</span> by
#       <a class="hnuser" href="/profile/727">kennybbb</a>
# <a class="age" href="/post/2104">2 days ago</a> |
#       <a href="/post/2104">
#
#           discuss
#
#       </a>
# </td>
# </tr>
# <tr class="spacer" style="height:5px"></tr>
# <!-- repeat this block n times-->
# <tr class="morespace" style="height:10px"></tr>
# <tr>
# <td colspan="2"></td>
# <td class="title"><a class="morelink" href="
#                          /2
#                          " rel="next">More</a></td>
# </tr>
# </table>

# %%
rows = table.find_all(['a', 'span'], {'class': ['storylink', 'sitestr', 'hnuser', 'score', 'age']})
rows_parsed = [row.text for row in rows]

rows_parsed
# Out:
# ['ai-jobs.net now with jobmarks for AI/ML/DS jobs',
#  'ai-jobs.net',
#  '\n        2 points',
#  'pat',
#  '1 days ago',
#  '📚 The online courses you must take to be a better Data Scientist',
#  'medium.com',
#  '\n        4 points',
#  'thegurus',
#  '3 days ago',
#  'How to build fair ML models?',
#  'medium.com',
#  '\n        3 points',
#  'acingai',
#  '3 days ago',
#  'Join the NLP Summit for FREE',
#  'johnsnowlabs.com',
#  '\n        6 points',
#  'dsselevate',
#  '10 days ago',
#  'Find remote work in Data Science',
#  'dsremote.work',
#  '\n        7 points',
#  'pat',
#  '12 days ago',
#  'What are the tools for a team of any level to realize a container architecture?',
#  'medium.com',
#  '\n        4 points',
#  'acingai',
#  '8 days ago',
#  "Statistical Paradoxes & Logical Fallacies: Don't Believe the Lies your Data Tells",
#  'datascience.salon',
#  '\n        4 points',
#  'dsselevate',
#  '9 days ago',
#  'Python Data Science Interview Questions',
#  'interviewquery.com',
#  '\n        3 points',
#  'data4lyfe',
#  '8 days ago',
#  'Continuous Monitoring for data projects',
#  'medium.com',
#  '\n        2 points',
#  'acingai',
#  '10 days ago',
#  'Pandas Data Analysis Series',
#  'medium.com',
#  '\n        2 points',
#  'hippohoppy',
#  '14 days ago',
#  "Don't Democratize Data Science",
#  'kdnuggets.com',
#  '\n        1 point',
#  'thegurus',
#  '11 days ago',
#  'Deep Learning: What are activation functions? An overview using Python',
#  'deepflow.ai',
#  '\n        1 point',
#  'fabdrnd',
#  '9 days ago',
#  'The Secret of Painless WebSocket Tests with Spock Framework',
#  'evojam.com',
#  '\n        1 point',
#  'zmakowska',
#  '12 days ago',
#  'Funnel Transformer Explained',
#  'youtu.be',
#  '\n        1 point',
#  'henryailabs',
#  '10 days ago',
#  'Why Data Science Coaching?',
#  'interviewquery.com',
#  '\n        1 point',
#  'data4lyfe',
#  '10 days ago',
#  'How to Become a Data Scientist from Software Developer',
#  'towardsdatascience.com',
#  '\n        1 point',
#  'balavenkatesh',
#  '11 days ago',
#  'Three lines of code to implement a computer vision application using Tensorflow.js',
#  'towardsdatascience.com',
#  '\n        1 point',
#  'balavenkatesh',
#  '11 days ago',
#  'Machine learning environment setup within 10min!!!',
#  'usejournal.com',
#  '\n        1 point',
#  'balavenkatesh',
#  '11 days ago',
#  'Automated Machine Learning: The Free eBook',
#  'kdnuggets.com',
#  '\n        1 point',
#  'thegurus',
#  '10 days ago',
#  'Evolutions in data science',
#  'towardsdatascience.com',
#  '\n        1 point',
#  'italosayan',
#  '6 days ago',
#  'Easy Speech-to-Text with Python',
#  'kdnuggets.com',
#  '\n        1 point',
#  'thegurus',
#  '4 days ago',
#  'Generating cooking recipes using TensorFlow and LSTM Recurrent Neural Network: A step-by-step guide',
#  'github.com',
#  '\n        1 point',
#  'trekhleb',
#  '1 days ago',
#  'Explainable AI for the enterprise is about who owns AI projects in your company',
#  'deepflow.ai',
#  '\n        1 point',
#  'fabdrnd',
#  '3 days ago',
#  'If you had to start statistics all over again, where would you start?',
#  'kdnuggets.com',
#  '\n        1 point',
#  'thegurus',
#  '3 days ago',
#  'Lock & Unlock Ubunto system using OpenCV',
#  'linkedin.com',
#  '\n        1 point',
#  'balavenkatesh',
#  '1 days ago',
#  '10 Free Ways to Make Money For The Unemployed; Not All Fancy Though',
#  'com.ng',
#  '\n        1 point',
#  'kennybbb',
#  '2 days ago',
#  'Make money in Nigeria as a student & non student; invest #10-#50k now',
#  'com.ng',
#  '\n        1 point',
#  'kennybbb',
#  '2 days ago',
#  'Week 50 Pool Fixtures, Week 50 Pool Results – UK 2019/2020',
#  'com.ng',
#  '\n        1 point',
#  'kennybbb',
#  '2 days ago',
#  'Week 50 Pool Result; Classified Football Pools Fixtures – AUSSIE 2020',
#  'com.ng',
#  '\n        1 point',
#  'kennybbb',
#  '2 days ago',
#  'Sunbiz Forum Review; Register With #500 and Earn #5k Daily',
#  'com.ng',
#  '\n        1 point',
#  'kennybbb',
#  '2 days ago']

# %%
rows_parsed[0:5]
# Out:
# ['ai-jobs.net now with jobmarks for AI/ML/DS jobs',
#  'ai-jobs.net',
#  '\n        2 points',
#  'pat',
#  '1 days ago']

# %%
row_split = 5

rows_refactored = [rows_parsed[x:x+row_split] for x in range(0, len(rows_parsed), row_split)]

rows_refactored
# Out:
# [['ai-jobs.net now with jobmarks for AI/ML/DS jobs',
#   'ai-jobs.net',
#   '\n        2 points',
#   'pat',
#   '1 days ago'],
#  ['📚 The online courses you must take to be a better Data Scientist',
#   'medium.com',
#   '\n        4 points',
#   'thegurus',
#   '3 days ago'],
#  ['How to build fair ML models?',
#   'medium.com',
#   '\n        3 points',
#   'acingai',
#   '3 days ago'],
#  ['Join the NLP Summit for FREE',
#   'johnsnowlabs.com',
#   '\n        6 points',
#   'dsselevate',
#   '10 days ago'],
#  ['Find remote work in Data Science',
#   'dsremote.work',
#   '\n        7 points',
#   'pat',
#   '12 days ago'],
#  ['What are the tools for a team of any level to realize a container architecture?',
#   'medium.com',
#   '\n        4 points',
#   'acingai',
#   '8 days ago'],
#  ["Statistical Paradoxes & Logical Fallacies: Don't Believe the Lies your Data Tells",
#   'datascience.salon',
#   '\n        4 points',
#   'dsselevate',
#   '9 days ago'],
#  ['Python Data Science Interview Questions',
#   'interviewquery.com',
#   '\n        3 points',
#   'data4lyfe',
#   '8 days ago'],
#  ['Continuous Monitoring for data projects',
#   'medium.com',
#   '\n        2 points',
#   'acingai',
#   '10 days ago'],
#  ['Pandas Data Analysis Series',
#   'medium.com',
#   '\n        2 points',
#   'hippohoppy',
#   '14 days ago'],
#  ["Don't Democratize Data Science",
#   'kdnuggets.com',
#   '\n        1 point',
#   'thegurus',
#   '11 days ago'],
#  ['Deep Learning: What are activation functions? An overview using Python',
#   'deepflow.ai',
#   '\n        1 point',
#   'fabdrnd',
#   '9 days ago'],
#  ['The Secret of Painless WebSocket Tests with Spock Framework',
#   'evojam.com',
#   '\n        1 point',
#   'zmakowska',
#   '12 days ago'],
#  ['Funnel Transformer Explained',
#   'youtu.be',
#   '\n        1 point',
#   'henryailabs',
#   '10 days ago'],
#  ['Why Data Science Coaching?',
#   'interviewquery.com',
#   '\n        1 point',
#   'data4lyfe',
#   '10 days ago'],
#  ['How to Become a Data Scientist from Software Developer',
#   'towardsdatascience.com',
#   '\n        1 point',
#   'balavenkatesh',
#   '11 days ago'],
#  ['Three lines of code to implement a computer vision application using Tensorflow.js',
#   'towardsdatascience.com',
#   '\n        1 point',
#   'balavenkatesh',
#   '11 days ago'],
#  ['Machine learning environment setup within 10min!!!',
#   'usejournal.com',
#   '\n        1 point',
#   'balavenkatesh',
#   '11 days ago'],
#  ['Automated Machine Learning: The Free eBook',
#   'kdnuggets.com',
#   '\n        1 point',
#   'thegurus',
#   '10 days ago'],
#  ['Evolutions in data science',
#   'towardsdatascience.com',
#   '\n        1 point',
#   'italosayan',
#   '6 days ago'],
#  ['Easy Speech-to-Text with Python',
#   'kdnuggets.com',
#   '\n        1 point',
#   'thegurus',
#   '4 days ago'],
#  ['Generating cooking recipes using TensorFlow and LSTM Recurrent Neural Network: A step-by-step guide',
#   'github.com',
#   '\n        1 point',
#   'trekhleb',
#   '1 days ago'],
#  ['Explainable AI for the enterprise is about who owns AI projects in your company',
#   'deepflow.ai',
#   '\n        1 point',
#   'fabdrnd',
#   '3 days ago'],
#  ['If you had to start statistics all over again, where would you start?',
#   'kdnuggets.com',
#   '\n        1 point',
#   'thegurus',
#   '3 days ago'],
#  ['Lock & Unlock Ubunto system using OpenCV',
#   'linkedin.com',
#   '\n        1 point',
#   'balavenkatesh',
#   '1 days ago'],
#  ['10 Free Ways to Make Money For The Unemployed; Not All Fancy Though',
#   'com.ng',
#   '\n        1 point',
#   'kennybbb',
#   '2 days ago'],
#  ['Make money in Nigeria as a student & non student; invest #10-#50k now',
#   'com.ng',
#   '\n        1 point',
#   'kennybbb',
#   '2 days ago'],
#  ['Week 50 Pool Fixtures, Week 50 Pool Results – UK 2019/2020',
#   'com.ng',
#   '\n        1 point',
#   'kennybbb',
#   '2 days ago'],
#  ['Week 50 Pool Result; Classified Football Pools Fixtures – AUSSIE 2020',
#   'com.ng',
#   '\n        1 point',
#   'kennybbb',
#   '2 days ago'],
#  ['Sunbiz Forum Review; Register With #500 and Earn #5k Daily',
#   'com.ng',
#   '\n        1 point',
#   'kennybbb',
#   '2 days ago']]

# %%
import pandas as pd

df = pd.DataFrame(rows_refactored, columns=['title', 'publication', 'points', 'author', 'time_ago'])

df.head()
# Out:
#                                                title       publication  \
# 0    ai-jobs.net now with jobmarks for AI/ML/DS jobs       ai-jobs.net
# 1  📚 The online courses you must take to be a bet...        medium.com
# 2                       How to build fair ML models?        medium.com
# 3                       Join the NLP Summit for FREE  johnsnowlabs.com
# 4                   Find remote work in Data Science     dsremote.work
#
#                points      author     time_ago
# 0  \n        2 points         pat   1 days ago
# 1  \n        4 points    thegurus   3 days ago
# 2  \n        3 points     acingai   3 days ago
# 3  \n        6 points  dsselevate  10 days ago
# 4  \n        7 points         pat  12 days ago

# %%
import re

# df['points'] = df['points'].str.replace(r'\D', '').astype(int)
df['points'] = df['points'].apply(lambda x: re.sub('\D', '', x)).astype(int)

df.head()
# Out:
#                                                title       publication  \
# 0    ai-jobs.net now with jobmarks for AI/ML/DS jobs       ai-jobs.net
# 1  📚 The online courses you must take to be a bet...        medium.com
# 2                       How to build fair ML models?        medium.com
# 3                       Join the NLP Summit for FREE  johnsnowlabs.com
# 4                   Find remote work in Data Science     dsremote.work
#
#    points      author     time_ago
# 0       2         pat   1 days ago
# 1       4    thegurus   3 days ago
# 2       3     acingai   3 days ago
# 3       6  dsselevate  10 days ago
# 4       7         pat  12 days ago

# %%
df.dtypes
# Out:
# title          object
# publication    object
# points          int64
# author         object
# time_ago       object
# dtype: object

# %% [markdown]
# ### 2.2 Pandas read_html

# %%
pd.read_html(url)
# Out:
# [                                                   0
#  0       DataTau  new |  ask |  show |  submit  login
#  1  1.  ai-jobs.net now with jobmarks for AI/ML/DS...
#  2  Made with ❤️ by The Gurus |  Support |  Contac...,
#      0                                      1      2
#  0 NaN  DataTau  new |  ask |  show |  submit  login,
#         0   1                                                  2
#  0    1.0 NaN  ai-jobs.net now with jobmarks for AI/ML/DS job...
#  1    NaN NaN            2 points by  pat  1 days ago |  discuss
#  2    NaN NaN                                                NaN
#  3    2.0 NaN  📚 The online courses you must take to be a bet...
#  4    NaN NaN       4 points by  thegurus  3 days ago |  discuss
#  ..   ...  ..                                                ...
#  87  30.0 NaN  Sunbiz Forum Review; Register With #500 and Ea...
#  88   NaN NaN        1 point by  kennybbb  2 days ago |  discuss
#  89   NaN NaN                                                NaN
#  90   NaN NaN                                                NaN
#  91   NaN NaN                                               More
#
#  [92 rows x 3 columns]]

# %%
type(pd.read_html(url))
# Out:
# list

# %%
len(pd.read_html(url))
# Out:
# 3

# %%
type(pd.read_html(url)[0])
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_html(url, attrs={'class':'itemlist'})
# Out:
# [       0   1                                                  2
#  0    1.0 NaN  ai-jobs.net now with jobmarks for AI/ML/DS job...
#  1    NaN NaN            2 points by  pat  1 days ago |  discuss
#  2    NaN NaN                                                NaN
#  3    2.0 NaN  📚 The online courses you must take to be a bet...
#  4    NaN NaN       4 points by  thegurus  3 days ago |  discuss
#  ..   ...  ..                                                ...
#  87  30.0 NaN  Sunbiz Forum Review; Register With #500 and Ea...
#  88   NaN NaN        1 point by  kennybbb  2 days ago |  discuss
#  89   NaN NaN                                                NaN
#  90   NaN NaN                                                NaN
#  91   NaN NaN                                               More
#
#  [92 rows x 3 columns]]

# %%
pd.read_html(url, attrs={'class':'itemlist'})[0]
# Out:
#        0   1                                                  2
# 0    1.0 NaN  ai-jobs.net now with jobmarks for AI/ML/DS job...
# 1    NaN NaN            2 points by  pat  1 days ago |  discuss
# 2    NaN NaN                                                NaN
# 3    2.0 NaN  📚 The online courses you must take to be a bet...
# 4    NaN NaN       4 points by  thegurus  3 days ago |  discuss
# ..   ...  ..                                                ...
# 87  30.0 NaN  Sunbiz Forum Review; Register With #500 and Ea...
# 88   NaN NaN        1 point by  kennybbb  2 days ago |  discuss
# 89   NaN NaN                                                NaN
# 90   NaN NaN                                                NaN
# 91   NaN NaN                                               More
#
# [92 rows x 3 columns]

# %%
# for scraping the rest of DataTau

num_pages = 10

def function_to_parse_single_page(url):
    pass


for i in range(num_pages):
    url = f'https://datatau.net/new/{i+1}'
    
    function_to_parse_single_page(url)
    
    print(f'page {i+1} parsed!')
# Out:
# page 1 parsed!
# page 2 parsed!
# page 3 parsed!
# page 4 parsed!
# page 5 parsed!
# page 6 parsed!
# page 7 parsed!
# page 8 parsed!
# page 9 parsed!
# page 10 parsed!

# %% [markdown]
# <div style="padding-top: 25px; float: right">
#     <div>
#         <i>&nbsp;&nbsp;© Copyright by</i>
#     </div>
#     <div>
#         <a href="https://whiteboxml.com">
#             <img src="https://whiteboxml.com/static/img/logo/black_bg_white.svg" width="125">
#         </a>
#     </div>
# </div>
