# %% [markdown]
# <div style="float:right; padding-top: 15px; padding-right: 15px">
#     <div>
#         <a href="https://whiteboxml.com">
#             <img src="https://whiteboxml.com/static/img/logo/black_bg_white.svg" width="250">
#         </a>
#     </div>
# </div>

# %% [markdown]
# # exploratory data visualization charts

# %% [markdown]
# ## 0. introduction

# %% [markdown]
# * **EDA is one of the most important and underrated parts of Data Science. explore your data at the beginning of any project**
# * let's keep learning about plots... 🧐
#     * Box Plots
#     * Violin Plots
#     * Histograms
#     * Bar Plots
# * let's use different libraries (pandas vs seaborn)...

# %% [markdown]
# ## 1. data loading

# %%
import pandas as pd

# %%
vehicles = pd.read_csv('./data/vehicles.csv')

# %% [markdown]
# ## 2. visualization setup

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import set_matplotlib_formats

set_matplotlib_formats('svg')

sns.set_style('whitegrid')

# %%
# %matplotlib inline

# %% [markdown]
# ## 3. visualizations

# %% [markdown]
# ### 3.1 box plot (pandas vs seaborn)

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.boxplot.html

# %%
vehicles['Combined MPG'].plot(kind='box', figsize=(8,8));

# %%
vehicles.boxplot(column=['Combined MPG'], 
                 rot=45,
                 by=['Cylinders'],
                 fontsize=15,
                 figsize=(8, 8));

# %%
fig = plt.figure(figsize=(8, 8))
ax = sns.boxplot(x='Cylinders', y='Combined MPG', data=vehicles);
ax.set_xticklabels(ax.get_xticklabels(),rotation=45);

# %%
fig = plt.figure(figsize=(64, 8))
ax = sns.boxplot(hue='Fuel Type', y='Highway MPG', x='Cylinders', data=vehicles, palette='Set3');
ax.set_xticklabels(ax.get_xticklabels(),rotation=45);

# %% [markdown]
# ### 3.2 violin plots (seaborn)

# %%
fig = plt.figure(figsize=(10, 8))
ax = sns.violinplot(x='Cylinders', y='Combined MPG', data=vehicles);

# %%
fig = plt.figure(figsize=(64, 8))
ax = sns.violinplot(x='Fuel Type', 
                    y='Highway MPG', 
                    hue='Cylinders', 
                    data=vehicles, 
                    palette='Set3');
ax.set_xticklabels(ax.get_xticklabels(),rotation=45);

# %% [markdown]
# ### 3.3 histograms (pandas vs seaborn)

# %% [markdown]
# https://seaborn.pydata.org/generated/seaborn.distplot.html

# %%
vehicles['Fuel Barrels/Year'].hist();

# %%
vehicles['Fuel Barrels/Year'].hist(bins=50);

# %%
sns.distplot(vehicles['Fuel Barrels/Year'], bins=10);

# %% [markdown]
# ### 3.4 barplots

# %%
vehicles['Cylinders'].value_counts().plot.bar();

# %%
fig = plt.figure(figsize=(32, 8))
ax = sns.barplot(x='Fuel Type', y='Highway MPG', hue='Cylinders', data=vehicles)

# %% [markdown]
# <div style="padding-top: 25px; float: right">
#     <div>
#         <i>&nbsp;&nbsp;© Copyright by</i>
#     </div>
#     <div>
#         <a href="https://whiteboxml.com">
#             <img src="https://whiteboxml.com/static/img/logo/black_bg_white.svg" width="125">
#         </a>
#     </div>
# </div>
